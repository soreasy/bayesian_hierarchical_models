# %%
import pymc3 as pm
import theano
import theano.tensor as tt

import pandas as pd
import numpy as np
from datetime import datetime, timedelta, date

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('ggplot')

# %%
# df = pd.read_csv('weekly_dmd.csv')
df = pd.read_csv('weekly_dmd_new.csv')
df['date'] = pd.to_datetime(df.date).apply(lambda x: x.date())
df = df.set_index(df.date)
df.index.rename('date_idx', inplace=True)
df.head(2)
# Out:
#             zone_id        date  total_demand_new  total_demand_new_lag1  \
# date_idx
# 2017-07-10        1  2017-07-10       2156.459303                    NaN
# 2017-07-10      597  2017-07-10          0.000000                    NaN
#
#             total_demand_new_lag2  total_demand_new_lag3  \
# date_idx
# 2017-07-10                    NaN                    NaN
# 2017-07-10                    NaN                    NaN
#
#             total_demand_new_lag-1  total_demand_new_lag-2  \
# date_idx
# 2017-07-10             2110.494687             2194.632691
# 2017-07-10                0.000000                0.000000
#
#             total_demand_new_lag-3  smoothed_total_demand  year  \
# date_idx
# 2017-07-10             2186.039578                    NaN  2017
# 2017-07-10                0.000000                    NaN  2017
#
#             total_demand_new_lag4  t4w_total_demand  month  week  day  \
# date_idx
# 2017-07-10                    NaN               NaN      7    28   10
# 2017-07-10                    NaN               NaN      7    28   10
#
#             t4w_total_demand_lag2  szn_factor
# date_idx
# 2017-07-10                    NaN         NaN
# 2017-07-10                    NaN         NaN

# %%
df.date.max()
# Out:
# datetime.date(2021, 7, 5)

# %%
covid_start_idx = date(2020,2,17)

df_prep = df.loc[(df.date < covid_start_idx)
                | (df.date >= covid_start_idx + timedelta(weeks=52))].sort_values('date')

df_prep['y_obs'] = df_prep.total_demand_new
# df_prep['y_obs'] = df_prep.smoothed_total_demand
df_prep['covid_start_m1'] = df_prep.date.apply(lambda x: 1.0 if x == covid_start_idx - timedelta(weeks=1) else 0)

# %%
# Unblocking SAGE V2
    # can mostly be done with what we have today
    # **caveat - scalability of current forecast (maybe can use naive method for majority of zones, use new method for largest zones)

# Longer-term improvements to gap forecasts
    # adding features to current forecasts
    # adding dampening effect to current forecast's trend component
    # hierarchical/multivariate extension of current forecast

# %%
def fit_hw_model(zdf, initial_lvl_upper):
    szn_len = 52

    with pm.Model() as hw_model:
    #     initial_level = pm.Normal(f'initial_level', mu=3000, sigma=400)
#         initial_level = pm.Uniform(f'initial_level', lower=0, upper=5000)
        initial_level = pm.Uniform(f'initial_level', lower=0, upper=initial_lvl_upper)
        smoothing_level = pm.Uniform('smoothing_level', lower=0, upper=1)
#         smoothing_level = pm.Normal('smoothing_level', mu=0.5, sigma=0.5)

    #     initial_trend = pm.Normal(f'initial_trend', mu=0, sigma=100)
#         initial_trend = pm.Uniform(f'initial_trend', lower=-1000, upper=1000)
        initial_trend = pm.Uniform(f'initial_trend', lower=-initial_lvl_upper/2, upper=initial_lvl_upper/2)
        smoothing_trend = pm.Uniform('smoothing_trend', lower=0, upper=1)
    #     smoothing_trend = pm.Normal('smoothing_trend', mu=0.5, sigma=0.5)

        if len(zdf) < szn_len*2.5:
#         if len(zdf) < szn_len*2:
#             initial_szns = pm.Deterministic('initial_szns', 1.0, dims=(szn_len))
            initial_szns = tt.as_tensor_variable([1.0 for i in range(52)])
            smoothing_season = 0.0
#             smoothing_season = pm.Deterministic('smoothing_season', 1.0)
        else:
            initial_szns = pm.Normal('initial_szns', mu=1.0, sigma=0.2, shape=(szn_len))
        #     initial_szns = pm.Uniform('initial_szns', lower=0.7, upper=1.3, shape=(szn_len))
        #     smoothing_season = pm.Uniform('smoothing_season', lower=0, upper=1)
        #     smoothing_season = pm.Uniform('smoothing_season', lower=0, upper=1)
        #     smoothing_season = pm.Uniform('smoothing_season', lower=0, upper=1-smoothing_level)
            smoothing_season = pm.TruncatedNormal('smoothing_season', mu=0.2, sigma=0.5, lower=0, upper=0.8)
        #     smoothing_season = pm.Normal('smoothing_season', mu=0.5, sigma=0.5)

        ys = tt.as_tensor_variable(zdf['y_obs'])
        is_covid_start = tt.as_tensor_variable(zdf['covid_start_m1'])
    #     covid_level_change = pm.Normal('covid_level_change', mu=15000, sigma=2000)
        covid_level_change = pm.Uniform('covid_level_change', lower=0, upper=5000)
#         covid_level_change = pm.Normal('covid_level_change', mu=2000, sigma=1000)
    #     covid_level_change2 = pm.Normal('covid_level_change2', mu=20000, sigma=2000)
        covid_level_change2 = pm.Uniform('covid_level_change2', lower=0, upper=5000)
    #     covid_level_change2 = pm.Normal('covid_level_change2', mu=covid_level_change, sigma=1000)
    #     covid_level_change2 = pm.Normal('covid_level_change2', mu=covid_level_change, sigma=1000)

        def hw_component_wise(y, covid_start, prior_level, prior_trend, szn_m52):
            updated_szn = smoothing_season * y / (prior_level + prior_trend) + (1 - smoothing_season) * szn_m52


            next_level = smoothing_level * (y/szn_m52) + (1 - smoothing_level)*(prior_level + prior_trend) + covid_start*covid_level_change
            next_trend = smoothing_trend * (next_level - prior_level) + (1 - smoothing_trend)*prior_trend - covid_start*smoothing_trend*covid_level_change2


            return next_level, next_trend, updated_szn

        outputs, updates = theano.scan(hw_component_wise,
               sequences = [
                   ys[1:],
#                    ys[szn_len:],
                   is_covid_start[1:]
#                    is_covid_start[szn_len:]
        #            post_covid[szn_len:]
               ],
               outputs_info = [
                   dict(initial = initial_level, taps=None),
                   dict(initial = initial_trend, taps=None),
                   dict(initial = initial_szns, taps=[-szn_len])
               ], 
        #            non_sequences = 
               )


        levels = outputs[0]
        trends = outputs[1]
        seasons = outputs[2]


        levels_f = pm.math.concatenate([initial_level.reshape(1,1), levels[:-1]])
        trends_f = pm.math.concatenate([initial_trend.reshape(1,1), trends[:-1]])
        seasons_f = pm.math.concatenate([initial_szns, seasons[:-szn_len]])

        levels_and_trends = pm.math.stack([levels_f, trends_f])
        level_plus_trend = levels_and_trends.sum(axis=0)

        level_plus_trend_and_seasons = pm.math.stack([level_plus_trend, seasons_f])
        y_hats = level_plus_trend_and_seasons.prod(axis=0)

        sig = pm.HalfCauchy('sigma', beta=10)
#         y_like = pm.Normal('y_like', mu=y_hats, sigma=sig, observed=zdf.iloc[szn_len-1:-1, :]['y_obs_lag-1'])
        y_like = pm.Normal('y_like', mu=y_hats, sigma=sig, observed=zdf.iloc[:-1, :]['y_obs_lag-1'])
        
    map_estimate = pm.find_MAP(model=hw_model)
    
    return map_estimate, ys, is_covid_start

# %%
def predict(map_estimate, ys, is_covid_start, horizon):
    
    if 'initial_szns' in map_estimate:
        szn_estimates = tt.as_tensor_variable(map_estimate['initial_szns'])
        szn_smoother = map_estimate['smoothing_season']
    else:
        szn_estimates = tt.as_tensor_variable([1.0 for i in range(52)])
        szn_smoother = 0.0

    def hw_component_wise_final(y, covid_start, prior_level, prior_trend, szn_m52):
            updated_szn = szn_smoother * y / (prior_level + prior_trend) + (1 - szn_smoother) * szn_m52
#             updated_szn = map_estimate['smoothing_season'] * y / (prior_level + prior_trend) + (1 - map_estimate['smoothing_season']) * szn_m52


            next_level = map_estimate['smoothing_level'] * (y/szn_m52) + (1 - map_estimate['smoothing_level'])*(prior_level + prior_trend) + covid_start*map_estimate['covid_level_change']
            next_trend = map_estimate['smoothing_trend'] * (next_level - prior_level) + (1 - map_estimate['smoothing_trend'])*prior_trend - covid_start*map_estimate['smoothing_trend']*map_estimate['covid_level_change2']


            return next_level, next_trend, updated_szn

    outputs, updates = theano.scan(hw_component_wise_final,
               sequences = [
#                    ys[szn_len:],
                   ys[1:],
#                    is_covid_start[szn_len:]
                   is_covid_start[1:]
        #            post_covid[szn_len:]
               ],
               outputs_info = [
                   dict(initial = map_estimate['initial_level'], taps=None),
                   dict(initial = map_estimate['initial_trend'], taps=None),
                   dict(initial = szn_estimates, taps=[-szn_len])
#                    dict(initial = tt.as_tensor_variable(map_estimate['initial_szns']), taps=[-szn_len])
               ], 
        #            non_sequences = 
               )
    
    levels = outputs[0]
    trends = outputs[1]
    seasons = outputs[2]

    levels_f = pm.math.concatenate([map_estimate['initial_level'].reshape(1), levels[:-1]])
    trends_f = pm.math.concatenate([map_estimate['initial_trend'].reshape(1), trends[:-1]])
#     seasons_f = pm.math.concatenate([map_estimate['initial_szns'], seasons[:-szn_len]])
    seasons_f = pm.math.concatenate([szn_estimates, seasons[:-szn_len]])

    levels_and_trends = pm.math.stack([levels_f, trends_f])
    level_plus_trend = levels_and_trends.sum(axis=0)

    level_plus_trend_and_seasons = pm.math.stack([level_plus_trend, seasons_f])
    y_hats = level_plus_trend_and_seasons.prod(axis=0)
    
    corresponding_szn_idx = (horizon - szn_len) - 1
#     szn_estimate = seasons_f.get_test_value()[corresponding_szn_idx]
    szn_estimate = seasons.get_test_value()[corresponding_szn_idx]

#     pred = (levels_f.get_test_value()[-1] + horizon*trends_f.get_test_value()[-1])*szn_estimate
    pred = (levels.get_test_value()[-1] + horizon*trends.get_test_value()[-1])*szn_estimate
#     return pred, levels, trends, seasons, corresponding_szn_idx, szn_estimate, y_hats
    return pred, levels_f, trends_f, seasons_f, seasons, corresponding_szn_idx, szn_estimate, y_hats

# %%
latest_f_date = df_prep.date.max() + timedelta(weeks=1)
latest_f_date
# Out:
# datetime.date(2021, 7, 12)

# %%
zz = [18,  307,  438,  266,   90,  541,  272,  692,  475,  348,  273,
        178,  495,  694,  190,  707,  161,  521,  452,  489,  785,  942,
        972,  861,  973,  943,  975,  981,  974, 1002,  983, 1001,  839,
        714,    1,  783,  989,  787,   79,  945,  169,   37,  186,   76,
        620,  441,   32,  184,  477,  357,  530,  616,  167,  617,  437,
         38,  166, 1029,  428,  853,   43,   16,  982,  713,  988,  262,
        840,  144,  709,  181,  204,  440,  225,  245,  185,  104,  182,
        103,  439,   50,  946,  980,   27,  979,  183,  786,  131,   33,
        392,   87]

# %%
HORIZON = 2
szn_len = 52

# %%
### walk-forward validation

idx_outer = 1
pred_for_dates, zone_ids, preds, smoothing_levels, smoothing_trends, smoothing_seasons = [], [], [], [], [], []
for f_date in [latest_f_date]:
#     print(f'iter {idx_outer}/{len(test_dates2)}')
#     idx_outer += 1
    
    idx_inner = 1
    for z_id in zz:
        print(f'inner iter {idx_inner}')
        
        zdf = df_prep.loc[(df_prep.zone_id == z_id)
                            & (df_prep.date < f_date)
                            & (df_prep['y_obs'] > 0)
                           ]
    
        third_week = zdf.date.unique()[2]
        zdf = zdf.loc[zdf.date > third_week]
        
        
        pad_df = pd.DataFrame(columns = zdf.columns)
        pad_df.loc[0, 'zone_id'] = z_id
        zdf = pd.concat([pad_df, zdf])
        
        zdf['y_obs_lag-1'] = zdf.y_obs.shift(-1)
        initial_lvl_upper = zdf.head()['y_obs_lag-1'].max()
        
        map_estimate, ys, is_covid_start = fit_hw_model(zdf, initial_lvl_upper)
        pred, levels_f, trends_f, seasons_f, seasons, corresponding_szn_idx, szn_estimate, yhats = predict(map_estimate, ys, is_covid_start, HORIZON+1)
        
        pred_for_date = f_date + timedelta(weeks=HORIZON)
        
        pred_for_dates.append(pred_for_date)
        zone_ids.append(z_id)
        preds.append(pred)
        smoothing_levels.append(map_estimate['smoothing_level'])
        smoothing_trends.append(map_estimate['smoothing_trend'])
        if 'smoothing_season' in map_estimate:
            smoothing_seasons.append(map_estimate['smoothing_season'])
        else:
            smoothing_seasons.append(0.0)
        idx_inner += 1
        
res = pd.DataFrame({'pred_for_date': pred_for_dates,
                        'zone_id': zone_ids,
                        'pred': preds,
                        'smoothing_level': smoothing_levels,
                        'smoothing_trend': smoothing_trends,
                        'smoothing_season': smoothing_seasons})

res.pred_for_date = pd.to_datetime(res.pred_for_date)
# Out:
# inner iter 1
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='414' class='' max='414' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [414/414 00:06<00:00 logp = -802.42, ||grad|| = 0.072367]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 2
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1274' class='' max='1274' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1274/1274 00:22<00:00 logp = -549.66, ||grad|| = 0.21757]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 3
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1232' class='' max='1232' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1232/1232 00:18<00:00 logp = -487.59, ||grad|| = 0.39258]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 4
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1667' class='' max='1667' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1667/1667 00:27<00:00 logp = -506.22, ||grad|| = 0.84435]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 5
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1026' class='' max='1026' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1026/1026 00:14<00:00 logp = -642.52, ||grad|| = 0.11795]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 6
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='815' class='' max='815' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [815/815 00:10<00:00 logp = -469.57, ||grad|| = 0.30542]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 7
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2406' class='' max='2406' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2406/2406 00:39<00:00 logp = -572.76, ||grad|| = 0.45909]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 8
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='66' class='' max='66' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [66/66 00:00<00:00 logp = -612.57, ||grad|| = 0.14452]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 9
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1101' class='' max='1101' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1101/1101 00:17<00:00 logp = -518.86, ||grad|| = 0.58375]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 10
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1740' class='' max='1740' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1740/1740 00:28<00:00 logp = -507.29, ||grad|| = 0.45375]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 11
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='929' class='' max='929' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [929/929 00:12<00:00 logp = -531.37, ||grad|| = 0.95165]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 12
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1308' class='' max='1308' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1308/1308 00:23<00:00 logp = -583.78, ||grad|| = 0.20065]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 13
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1907' class='' max='1907' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1907/1907 00:27<00:00 logp = -519.58, ||grad|| = 0.54881]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 14
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1166' class='' max='1166' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1166/1166 00:17<00:00 logp = -437.26, ||grad|| = 0.37903]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 15
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='665' class='' max='665' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [665/665 00:09<00:00 logp = -482.13, ||grad|| = 0.72079]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 16
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2673' class='' max='2673' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2673/2673 00:34<00:00 logp = -416.81, ||grad|| = 0.62897]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 17
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1325' class='' max='1325' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1325/1325 00:24<00:00 logp = -484.2, ||grad|| = 0.38323]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 18
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1193' class='' max='1193' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1193/1193 00:20<00:00 logp = -421.17, ||grad|| = 0.33519]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 19
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='485' class='' max='485' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [485/485 00:08<00:00 logp = -610.07, ||grad|| = 0.15176]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 20
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1289' class='' max='1289' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1289/1289 00:22<00:00 logp = -413.12, ||grad|| = 0.62544]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 21
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='76' class='' max='76' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [76/76 00:01<00:00 logp = -858.6, ||grad|| = 0.025949]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 22
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='57' class='' max='57' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [57/57 00:00<00:00 logp = -765, ||grad|| = 0.014937]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 23
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00<00:00 logp = -722.71, ||grad|| = 0.012584]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 24
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:01<00:00 logp = -869.27, ||grad|| = 0.030646]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 25
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00<00:00 logp = -784.95, ||grad|| = 0.51352]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 26
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='58' class='' max='58' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [58/58 00:00<00:00 logp = -842.31, ||grad|| = 0.02333]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 27
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='74' class='' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [74/74 00:00<00:00 logp = -696.9, ||grad|| = 0.0073855]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 28
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='48' class='' max='48' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [48/48 00:00<00:00 logp = -633.18, ||grad|| = 0.18206]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 29
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='55' class='' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [55/55 00:00<00:00 logp = -802.41, ||grad|| = 0.015784]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 30
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='59' class='' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [59/59 00:00<00:00 logp = -618.52, ||grad|| = 4.3436]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 31
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:00<00:00 logp = -628.8, ||grad|| = 0.0076067]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 32
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='65' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [65/65 00:00<00:00 logp = -625.08, ||grad|| = 0.014954]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 33
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='63' class='' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [63/63 00:00<00:00 logp = -708.51, ||grad|| = 0.12485]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 34
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='708' class='' max='708' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [708/708 00:11<00:00 logp = -636.21, ||grad|| = 0.75726]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 35
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='206' class='' max='206' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [206/206 00:03<00:00 logp = -860.4, ||grad|| = 0.44342]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 36
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='61' class='' max='61' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [61/61 00:00<00:00 logp = -690.97, ||grad|| = 0.048124]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 37
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='80' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [80/80 00:00<00:00 logp = -687.18, ||grad|| = 0.26032]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 38
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='67' class='' max='67' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [67/67 00:00<00:00 logp = -724.38, ||grad|| = 0.043553]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 39
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='423' class='' max='423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [423/423 00:08<00:00 logp = -871.25, ||grad|| = 0.11727]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 40
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='49' class='' max='49' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [49/49 00:00<00:00 logp = -676.98, ||grad|| = 41.717]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 41
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1344' class='' max='1344' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1344/1344 00:26<00:00 logp = -587.98, ||grad|| = 0.38768]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 42
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1359' class='' max='1359' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1359/1359 00:23<00:00 logp = -638.59, ||grad|| = 0.43672]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 78
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='961' class='' max='961' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [961/961 00:15<00:00 logp = -614.5, ||grad|| = 0.34324]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 79
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2118' class='' max='2118' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2118/2118 00:35<00:00 logp = -536.22, ||grad|| = 0.29787]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 80
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='626' class='' max='626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [626/626 00:10<00:00 logp = -650.67, ||grad|| = 0.22223]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 81
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='74' class='' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [74/74 00:00<00:00 logp = -668.58, ||grad|| = 0.13626]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 82
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='49' class='' max='49' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [49/49 00:00<00:00 logp = -627.62, ||grad|| = 1.3228]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 83
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='308' class='' max='308' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [308/308 00:05<00:00 logp = -882.27, ||grad|| = 0.24327]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 84
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='69' class='' max='69' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [69/69 00:00<00:00 logp = -597.44, ||grad|| = 1.4401]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 85
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='600' class='' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [600/600 00:08<00:00 logp = -804.51, ||grad|| = 0.17218]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 86
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='73' class='' max='73' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [73/73 00:00<00:00 logp = -630.17, ||grad|| = 0.090558]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 87
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1032' class='' max='1032' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1032/1032 00:15<00:00 logp = -603.12, ||grad|| = 0.22479]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 88
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='659' class='' max='659' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [659/659 00:09<00:00 logp = -709.36, ||grad|| = 0.41023]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 89
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='740' class='' max='740' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [740/740 00:10<00:00 logp = -772.11, ||grad|| = 0.28039]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None
# inner iter 90
# WARNING (theano.scan.basic): Output initial_level (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output initial_trend (index 1) has a initial state but taps is explicitly set to None
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='396' class='' max='396' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [396/396 00:06<00:00 logp = -814.73, ||grad|| = 0.107]
#     </div>
# WARNING (theano.scan.basic): Output None (index 0) has a initial state but taps is explicitly set to None
# WARNING (theano.scan.basic): Output None (index 1) has a initial state but taps is explicitly set to None

# %%
# [X] produce demand forecasts for f_date
    # [X] translate to DoW using existing method for DoW distribution
# [...] produce supply forecasts for f_date
    # [] pull historical melt rates and just use DES or shorter-term HW w/ daily seasonality for this
        # [-] can do some quick backtest here to see if we want to use the covid-handling version or out-of-box
    # [] use existing in-funnel estimate
    
# [] combine with ratios
    # [] compare results to what they would be with perfect forecasts

# [] finish implementing hierarchical version while existing forecasts are running
    # [] this will help get around the issues currently facing with not having enough data to get seasonal estimates in many places
        
# [] maybe should consider taking median (not mean) when grouping by week, since the DoW adjustments are generated relative to period medians
# [] could also calculate the relative DoW factors in here, since it's not much code, so that it's being done on the adjusted demand data (to account for holiday effects)

# [] look at correlation w/ recent and solve week LD, avail, TTA for old and new
# [] look at zones where old didnt have gap and LD was high (or other metrics low)
    # [] if we didn't have a gap, would we have a gap even with perfect forecast?
# [] vice versa for above

# [] shouldnt we actually be able to get accuracy improvement impacts from backtesting too?
    # [] ie, we can see what sage would have done w/ perfect forecasts

# %%
### translate to DoW using existing method for DoW distribution
daily_dist = pd.read_csv('./daily_dist_f_date_8_09.csv')
# daily_dist = pd.read_csv('./daily_dist_f_date_8_02.csv')
# daily_dist = pd.read_csv('./daily_dist_f_date_7_26.csv')
# daily_dist = pd.read_csv('./daily_dist_f_date_7_19.csv')
# daily_dist = pd.read_csv('./daily_dist_f_date_6_28.csv')

daily_dist['pred_for_date'] = daily_dist.pred_for_date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())
daily_dist['forecast_date'] = daily_dist.forecast_date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())

daily_dist.head(2)
# Out:
#    zone_id forecast_date pred_for_date  total_supply_from_funnel  t7d_supply  \
# 0      466    2021-08-03    2021-08-16                 34.791792       870.0
# 1      466    2021-08-03    2021-08-17                 39.326009       870.0
#
#    median_dps  max_delivery_gap  forecasted_melt_old  \
# 0    1.095673         47.535498                0.986
# 1    1.095673         40.262252                0.980
#
#    forecasted_sessions_from_already_activated_shoppers_old  \
# 0                                         858.241579
# 1                                         852.511567
#
#    predicted_shopper_visits_old  ideal_supply_old  supply_deficit_old  \
# 0                    893.033371        806.138677          -86.894694
# 1                    891.837576        779.280001         -112.557575
#
#    ideal_ratio_old  delivery_gap_old  manual_adjustment_old
# 0         0.687037               0.0                   1.04
# 1         0.717754               0.0                   1.04

# %%
daily_dist.pred_for_date.min(), daily_dist.pred_for_date.max()
# Out:
# (datetime.date(2021, 8, 16), datetime.date(2021, 8, 22))

# %%
# bt = pd.read_csv('./demand_fcast_fdate_06_28_21.csv')
# bt = pd.read_csv('./demand_fcast_fdate_07_19_21.csv')
# bt = pd.read_csv('./demand_fcast_fdate_07_26_21.csv')
# bt = pd.read_csv('./demand_fcast_fdate_08_02_21.csv')
bt = pd.read_csv('./demand_fcast_fdate_08_02_21_new.csv')

bt['pred_for_week'] = bt.pred_for_date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())
bt['forecast_date'] = bt.pred_for_week - timedelta(weeks=2)

bt.drop(columns=['pred_for_date'], inplace=True)
bt.head(2)
# Out:
#    zone_id         pred  smoothing_level  smoothing_trend  smoothing_season  \
# 0      785  9453.010226         0.780716         0.207552          0.000130
# 1      942  8364.176341         0.558574         0.517546          0.000215
#
#   pred_for_week forecast_date
# 0    2021-08-16    2021-08-02
# 1    2021-08-16    2021-08-02

# %%
bt2 = bt.merge(daily_dist, on='zone_id')
bt2.shape
# Out:
# (630, 21)

# %%
bt2['dow'] = pd.to_datetime(bt2.pred_for_date).dt.day_name()

# %%
bt2.loc[bt2.zone_id == 1]
# Out:
#      zone_id         pred  smoothing_level  smoothing_trend  smoothing_season  \
# 98         1  3951.391854         0.677206         0.000258          0.000001
# 99         1  3951.391854         0.677206         0.000258          0.000001
# 100        1  3951.391854         0.677206         0.000258          0.000001
# 101        1  3951.391854         0.677206         0.000258          0.000001
# 102        1  3951.391854         0.677206         0.000258          0.000001
# 103        1  3951.391854         0.677206         0.000258          0.000001
# 104        1  3951.391854         0.677206         0.000258          0.000001
#
#     pred_for_week forecast_date_x forecast_date_y pred_for_date  \
# 98     2021-08-16      2021-08-02      2021-08-03    2021-08-16
# 99     2021-08-16      2021-08-02      2021-08-03    2021-08-17
# 100    2021-08-16      2021-08-02      2021-08-03    2021-08-18
# 101    2021-08-16      2021-08-02      2021-08-03    2021-08-19
# 102    2021-08-16      2021-08-02      2021-08-03    2021-08-20
# 103    2021-08-16      2021-08-02      2021-08-03    2021-08-21
# 104    2021-08-16      2021-08-02      2021-08-03    2021-08-22
#
#      total_supply_from_funnel  ...  median_dps  max_delivery_gap  \
# 98                  36.949925  ...         2.0        211.810749
# 99                  36.821469  ...         2.0        186.461161
# 100                 34.958888  ...         2.0        182.909967
# 101                 34.238023  ...         2.0        172.814519
# 102                 33.202384  ...         2.0        173.238180
# 103                 30.209447  ...         2.0        172.064281
# 104                 33.390900  ...         2.0        214.038288
#
#      forecasted_melt_old  \
# 98                 1.028
# 99                 0.996
# 100                1.005
# 101                0.988
# 102                0.978
# 103                0.913
# 104                0.862
#
#      forecasted_sessions_from_already_activated_shoppers_old  \
# 98                                         1378.930171
# 99                                         1335.263903
# 100                                        1347.811385
# 101                                        1324.431945
# 102                                        1311.545040
# 103                                        1224.074068
# 104                                        1156.518109
#
#      predicted_shopper_visits_old  ideal_supply_old  supply_deficit_old  \
# 98                    1415.880096        661.887231         -753.992865
# 99                    1372.085373        744.495792         -627.589580
# 100                   1382.770273        681.188557         -701.581716
# 101                   1358.669968        475.607153         -883.062815
# 102                   1344.747423        554.969621         -789.777803
# 103                   1254.283515        575.732368         -678.551147
# 104                   1189.909009        670.468856         -519.440152
#
#      ideal_ratio_old  delivery_gap_old        dow
# 98          0.131493               0.0     Monday
# 99          0.156202               0.0    Tuesday
# 100         0.154083               0.0  Wednesday
# 101         0.110020               0.0   Thursday
# 102         0.126578               0.0     Friday
# 103         0.134543               0.0   Saturday
# 104         0.127252               0.0     Sunday
#
# [7 rows x 21 columns]

# %%
# demand_dow_dist = pd.read_csv('./demand_dow_dist_f_date_6_28.csv')
# demand_dow_dist = pd.read_csv('./demand_dow_dist_f_date_7_19.csv')
# demand_dow_dist = pd.read_csv('./demand_dow_dist_f_date_7_26.csv')
demand_dow_dist = pd.read_csv('./demand_dow_dist_f_date_8_02.csv')
demand_dow_dist.head(2)
# Out:
#    zone_id     dow  demand_relative_to_period_mean
# 0        1  Friday                        0.929732
# 1        1  Monday                        1.107954

# %%
bt2 = bt2.merge(demand_dow_dist, on=['zone_id', 'dow'])
bt2.shape
# Out:
# (630, 23)

# %%
bt2['demand_pred'] = bt2.pred * bt2.demand_relative_to_period_mean

# %%
bt2.zone_id.unique()
# Out:
# array([ 785,  942,  972,  861,  973,  943,  975,  981, 1002,  974,  983,
#        1001,  839,  714,    1,  783,  989,  787,   79,  945,  946,  980,
#         786,  183,   27,  979,  131,   33,  392,   87,   43,   16,  982,
#         713,  988,  262,  840,  144,  709,  181,  204,  440,  225,  245,
#         185,  104,  182,  439,  103,  169,   50,  186,   37,  620,  441,
#          76,  184,   32,  530,  357,  477,  616,  617,  167,  437,  166,
#          38, 1029,   18,  428,  307,  853,  438,  541,  266,   90,  272,
#         348,  475,  178,  273,  495,  692,  521,  228,  161,  190,  168,
#         694,  707])

# %%
s = pd.read_csv('./supply_fcast_fdate_08_02_21_new.csv')
# s = pd.read_csv('./supply_fcast_fdate_08_02_21.csv')
# s = pd.read_csv('./supply_fcast_fdate_07_26_21.csv')
# s = pd.read_csv('./supply_fcast_fdate_07_19_21.csv')
# s = pd.read_csv('./supply_fcast_fdate_06_28_21.csv')

# s1 = pd.read_csv('./supply_fcast_fdate_07_19_21.csv')
# s2 = pd.read_csv('./supply_fcast_fdate_07_19_21_addition.csv')
# s = pd.concat([s1, s2])

s['pred_for_date'] = s.pred_for_date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())
s['forecast_date'] = s.forecast_date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())

# s.drop(columns=['date'], inplace=True)
s.rename(columns={'pred': 'forecasted_melt'}, inplace=True)
s.head(2)
# Out:
#    zone_id pred_for_date  forecasted_melt  horizon forecast_date
# 0      785    2021-08-16         0.919307       13    2021-08-03
# 1      785    2021-08-21         0.768239       18    2021-08-03

# %%
bt3 = bt2.merge(s, on=['zone_id', 'pred_for_date'])
# bt3 = bt2.merge(s, on=['zone_id', 'forecast_date', 'pred_for_date'])
bt3.shape
# Out:
# (630, 27)

# %%
bt3['supply_pred'] = (bt3.forecasted_melt * bt3.t7d_supply) + bt3.total_supply_from_funnel
bt3['sd_ratio_pred'] = bt3.supply_pred / bt3.demand_pred

# %%
ideal_ratios = pd.read_clipboard()

# %%
ideal_ratios['ideal_ratio'] = ideal_ratios.weekday_ratio

# %%
ideal_ratios.head(2)
# Out:
#    zone_id  weekday_ratio  weekend_ratio notes  ideal_ratio
# 0        1           0.35            0.4   NaN         0.35
# 1       16           0.70            0.7   NaN         0.70

# %%
# ideal_ratios = pd.read_csv('./ideal_ratio_2021-04-27.csv')
# ideal_ratios.rename(columns={'ratio': 'ideal_ratio'}, inplace=True)
# ideal_ratios.head(2)
# Out:
#    zone_id      dow forecast_date  ideal_ratio       tta  \
# 0      564   Monday    2021-04-27     0.738054  2.462841
# 1      564  Tuesday    2021-04-27     0.687835  2.540449
#
#                                               Rk  \
# 0  [array([ 0.       ,  0.       , 27.3549374])]
# 1  [array([ 0.       ,  0.       , 36.8017314])]
#
#                             Xsolution                              Ysolution  \
# 0  [0.34602715 0.73805397 1.19982421]  [25.30881355  2.46284061  2.90739889]
# 1  [0.30995669 0.68783454 1.23596226]  [28.85405433  2.54044948  1.17318979]
#
#            a          b data_level data_pattern  remove_outlier  \
# 0  45.474084 -58.276556   zone_dow      regular           False
# 1  50.437955 -69.635214   zone_dow      regular           False
#
#   solution_method solution_pattern
# 0     break_point   valid_solution
# 1     break_point   valid_solution

# %%
set(bt3.zone_id) - set(ideal_ratios.zone_id)
# Out:
# set()

# %%
# bt3['dow'] = pd.to_datetime(bt3.pred_for_date).dt.day_name()
# bt4 = bt3.merge(ideal_ratios, on=['zone_id', 'dow'])

bt4 = bt3.merge(ideal_ratios, on='zone_id')
bt4.shape
# Out:
# (630, 33)

# %%
bt4.loc[bt4.zone_id == 1][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#     pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 98     2021-08-15     Sunday         0.35       0.270533
# 99     2021-08-16     Monday         0.35       0.309283
# 100    2021-08-17    Tuesday         0.35       0.343268
# 101    2021-08-18  Wednesday         0.35       0.352850
# 102    2021-08-19   Thursday         0.35       0.370888
# 103    2021-08-20     Friday         0.35       0.348926
# 104    2021-08-21   Saturday         0.35       0.340251

# %%
bt4.loc[bt4.zone_id == 1][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#     pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 98     2021-08-16     Monday         0.35       0.318548
# 99     2021-08-17    Tuesday         0.35       0.354098
# 100    2021-08-18  Wednesday         0.35       0.359666
# 101    2021-08-19   Thursday         0.35       0.380858
# 102    2021-08-20     Friday         0.35       0.365674
# 103    2021-08-21   Saturday         0.35       0.342195
# 104    2021-08-22     Sunday         0.35       0.265262

# %%
bt4.loc[bt4.zone_id == 942][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 7     2021-07-11     Sunday         0.65       0.483063
# 8     2021-07-12     Monday         0.65       0.546461
# 9     2021-07-13    Tuesday         0.65       0.606672
# 10    2021-07-14  Wednesday         0.65       0.610460
# 11    2021-07-15   Thursday         0.65       0.596418
# 12    2021-07-16     Friday         0.65       0.561563
# 13    2021-07-17   Saturday         0.65       0.536276

# %%
bt4.loc[bt4.zone_id == 942][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 7     2021-08-15     Sunday         0.65       0.449143
# 8     2021-08-16     Monday         0.65       0.539963
# 9     2021-08-17    Tuesday         0.65       0.582962
# 10    2021-08-18  Wednesday         0.65       0.580771
# 11    2021-08-19   Thursday         0.65       0.569875
# 12    2021-08-20     Friday         0.65       0.516885
# 13    2021-08-21   Saturday         0.65       0.492469

# %%
bt4.loc[bt4.zone_id == 18][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#     pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 476    2021-08-15     Sunday          0.9       0.938887
# 477    2021-08-16     Monday          0.9       1.068188
# 478    2021-08-17    Tuesday          0.9       1.148732
# 479    2021-08-18  Wednesday          0.9       1.235947
# 480    2021-08-19   Thursday          0.9       1.338029
# 481    2021-08-20     Friday          0.9       1.367039
# 482    2021-08-21   Saturday          0.9       1.321958

# %%
bt4.loc[bt4.zone_id == 975][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 42    2021-07-11     Sunday         0.63       0.405775
# 43    2021-07-12     Monday         0.63       0.510670
# 44    2021-07-13    Tuesday         0.63       0.554006
# 45    2021-07-14  Wednesday         0.63       0.562111
# 46    2021-07-15   Thursday         0.63       0.532216
# 47    2021-07-16     Friday         0.63       0.500814
# 48    2021-07-17   Saturday         0.63       0.504232

# %%
bt4.loc[bt4.zone_id == 975][['pred_for_date', 'dow', 'ideal_ratio', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow  ideal_ratio  sd_ratio_pred
# 42    2021-08-15     Sunday         0.63       0.435465
# 43    2021-08-16     Monday         0.63       0.571700
# 44    2021-08-17    Tuesday         0.63       0.631296
# 45    2021-08-18  Wednesday         0.63       0.634354
# 46    2021-08-19   Thursday         0.63       0.596811
# 47    2021-08-20     Friday         0.63       0.558939
# 48    2021-08-21   Saturday         0.63       0.514808

# %%
growth_factors = pd.read_clipboard()
growth_factors.head(2)
# Out:
#    Zone id  Target start date Target end date  Growth factor  \
# 0       785         7/31/2021        8/4/2021            1.0
# 1       942         7/31/2021        8/4/2021            1.0
#
#                   Comments          Zone name  Summer Demand  WMT NYC  COVID  \
# 0  Factor Inputs: [DOW]: 1  Orange County, CA            1.0      1.0   1.05
# 1  Factor Inputs: [DOW]: 1      San Diego, CA            1.0      1.0   1.05
#
#    Seasonality  Capacity off  High CM Oversupply  90th Perc TTA  \
# 0          1.0           1.0                 1.0           1.00
# 1          1.0           1.0                 1.0           0.96
#
#    DOW Adjustment  Weekly Deliv  Weekly after growth  Baseline
# 0             1.0         59397                59397       NaN
# 1             1.0         51817                51817       NaN

# %%
list(growth_factors)
# Out:
# ['Zone id ',
#  'Target start date',
#  'Target end date',
#  'Growth factor',
#  'Comments',
#  'Zone name',
#  'Summer Demand',
#  'WMT NYC',
#  'COVID',
#  'Seasonality',
#  'Capacity off',
#  'High CM Oversupply',
#  '90th Perc TTA',
#  'DOW Adjustment',
#  'Weekly Deliv',
#  'Weekly after growth',
#  'Baseline']

# %%
covid_only_factors = (growth_factors.loc[
    (growth_factors['Target start date'] == '8/16/2021')
    & (growth_factors['Target end date'] == '8/22/2021')]
                      [['Zone id ', 'COVID']]
                      .rename(columns={'Zone id ': 'zone_id', 'COVID': 'covid_multiplier'}))

covid_only_factors.head(2)
# Out:
#       zone_id  covid_multiplier
# 2686      785               1.1
# 2687      942               1.1

# %%
bt4.pred_for_date.min(), bt4.pred_for_date.max()
# Out:
# (datetime.date(2021, 8, 16), datetime.date(2021, 8, 22))

# %%
bt4 = bt4.merge(covid_only_factors, on='zone_id')
bt4.shape
# Out:
# (630, 40)

# %%
# bt4['ideal_supply'] = bt4.covid_multiplier * bt4.demand_pred * bt4.ideal_ratio
bt4['ideal_supply'] = bt4.demand_pred * bt4.ideal_ratio

bt4['supply_deficit'] = bt4.ideal_supply - bt4.supply_pred
bt4['supply_deficit_non_neg'] = np.maximum(bt4.supply_deficit, 0)
bt4['delivery_gap_pre_cap'] = bt4.supply_deficit_non_neg * bt4.median_dps
bt4['delivery_gap'] = np.minimum(bt4.delivery_gap_pre_cap, bt4.max_delivery_gap)

# %%
bt4['gap_diff'] = bt4.delivery_gap - bt4.delivery_gap_old

# %%
bt4.sort_values('gap_diff')[['zone_id', 'pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'ideal_supply', 'ideal_supply_old']].head(10)
# Out:
#      zone_id pred_for_date        dow     gap_diff  delivery_gap  \
# 97       714    2021-08-22     Sunday -1733.862348    843.881121
# 265      144    2021-08-22     Sunday  -607.680052     72.127034
# 167      183    2021-08-22     Sunday  -428.332632    159.061253
# 209       87    2021-08-22     Sunday  -397.298028      0.000000
# 400       32    2021-08-17    Tuesday  -346.584047      5.807998
# 401       32    2021-08-18  Wednesday  -332.267189      0.000000
# 363      186    2021-08-22     Sunday  -322.361691     39.420879
# 301      245    2021-08-16     Monday  -310.070433      0.000000
# 312      185    2021-08-20     Friday  -309.093367      0.000000
# 402       32    2021-08-19   Thursday  -303.737898     40.819277
#
#      delivery_gap_old  ideal_supply  ideal_supply_old
# 97        2577.743468   3507.946325       5575.782148
# 265        679.807086   1702.629314       2144.918898
# 167        587.393885   1521.221412       1772.022553
# 209        397.298028   1775.344708       2162.928110
# 400        352.392045    889.858733       1848.557216
# 401        332.267189    827.741911       1476.292228
# 363        361.782570   1184.769810       1432.094050
# 301        310.070433   1387.405712       1912.282178
# 312        309.093367    971.343409       1109.454132
# 402        344.557174    853.329624       1592.148879

# %%
bt4.sort_values('gap_diff')[['zone_id', 'pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'ideal_supply', 'ideal_supply_old']].head(10)
# Out:
#      zone_id pred_for_date        dow     gap_diff  delivery_gap  \
# 91       714    2021-08-15     Sunday -1081.544044    662.531831
# 63       974    2021-08-15     Sunday  -276.166820      0.000000
# 36       943    2021-08-16     Monday  -234.401032      0.000000
# 401       32    2021-08-17    Tuesday  -201.490549      9.944678
# 402       32    2021-08-18  Wednesday  -192.560452      0.000000
# 113      989    2021-08-16     Monday  -167.867043      0.000000
# 169       27    2021-08-16     Monday  -157.300829      0.000000
# 403       32    2021-08-19   Thursday  -147.586564     54.507514
# 171       27    2021-08-18  Wednesday  -132.600651      0.000000
# 172       27    2021-08-19   Thursday  -131.939694      0.000000
#
#      delivery_gap_old  ideal_supply  ideal_supply_old
# 91        1744.075875   3507.946325       4413.863520
# 63         276.166820   1677.833358       1944.893090
# 36         234.401032   2991.221603       3139.062677
# 401        211.435227    889.858733       1642.265582
# 402        192.560452    827.741911       1336.488669
# 113        167.867043   2345.909002       3105.124702
# 169        157.300829   1704.631230       3561.898918
# 403        202.094077    853.329624       1483.214447
# 171        132.600651   1444.278036       2534.942091
# 172        131.939694   1457.765932       2464.409273

# %%
bt4.sort_values('gap_diff')[['zone_id', 'pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'ideal_supply', 'ideal_supply_old']].tail(10)
# Out:
#      zone_id pred_for_date        dow    gap_diff  delivery_gap  \
# 55       981    2021-08-14   Saturday  233.247383    233.247383
# 60      1002    2021-08-12   Thursday  239.185918    239.185918
# 70       983    2021-08-08     Sunday  250.496026    250.496026
# 273      181    2021-08-08     Sunday  311.573371    311.573371
# 14       972    2021-08-08     Sunday  357.213780    357.213780
# 10       942    2021-08-11  Wednesday  362.333396    362.333396
# 11       942    2021-08-12   Thursday  365.184719    365.184719
# 12       942    2021-08-13     Friday  377.302247    377.302247
# 9        942    2021-08-10    Tuesday  377.881801    377.881801
# 294      225    2021-08-08     Sunday  536.509474    536.509474
#
#      delivery_gap_old  ideal_supply  ideal_supply_old
# 55                0.0   2036.746911       1675.756946
# 60                0.0   2707.424498       2086.384581
# 70                0.0   2615.871376       1894.300871
# 273               0.0   1919.461361       1447.460000
# 14                0.0   3857.911437       2639.724566
# 10                0.0   5031.238915       3562.556893
# 11                0.0   5013.137824       3495.071609
# 12                0.0   5107.285921       3895.442198
# 9                 0.0   5044.632240       4021.885913
# 294               0.0   1413.859998        594.137266

# %%
bt4.loc[bt4.zone_id == 32][['pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
                            'sd_ratio_pred', 'supply_pred', 'demand_pred']]
# Out:
#     pred_for_date        dow      gap_diff  delivery_gap  delivery_gap_old  \
# 399    2021-08-15     Sunday  1.500098e-10    224.136879        224.136879
# 400    2021-08-16     Monday -5.850614e+01    186.112310        244.618448
# 401    2021-08-17    Tuesday -2.014905e+02      9.944678        211.435227
# 402    2021-08-18  Wednesday -1.925605e+02      0.000000        192.560452
# 403    2021-08-19   Thursday -1.475866e+02     54.507514        202.094077
# 404    2021-08-20     Friday -9.161770e+01    106.833790        198.451490
# 405    2021-08-21   Saturday -1.144606e+01    188.365018        199.811077
#
#      max_delivery_gap  ideal_supply  ideal_supply_old  ideal_ratio  \
# 399        224.136879    952.964050       4222.406417         0.61
# 400        244.618448    999.644217       2474.486575         0.61
# 401        211.435227    889.858733       1642.265582         0.61
# 402        192.560452    827.741911       1336.488669         0.61
# 403        202.094077    853.329624       1483.214447         0.61
# 404        198.451490    863.085113       1660.648067         0.61
# 405        199.811077    843.684306       2087.087896         0.61
#
#      ideal_ratio_old  sd_ratio_pred  supply_pred  demand_pred
# 399         2.315701       0.450155   703.248587  1562.236147
# 400         1.389945       0.533633   874.496746  1638.761011
# 401         0.994502       0.605416   883.171634  1458.784808
# 402         0.884417       0.620058   841.389632  1356.953953
# 403         0.938814       0.583799   816.677146  1398.901023
# 404         1.003947       0.559227   791.246885  1414.893629
# 405         1.322012       0.518421   717.022047  1383.089026

# %%
bt4.loc[bt4.zone_id == 943][['pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
                            'sd_ratio_pred', 'supply_pred', 'demand_pred']]
# Out:
#    pred_for_date        dow      gap_diff  delivery_gap  delivery_gap_old  \
# 35    2021-08-15     Sunday  3.500418e-10    865.310232        865.310232
# 36    2021-08-16     Monday -2.344010e+02      0.000000        234.401032
# 37    2021-08-17    Tuesday  0.000000e+00      0.000000          0.000000
# 38    2021-08-18  Wednesday  0.000000e+00      0.000000          0.000000
# 39    2021-08-19   Thursday  0.000000e+00      0.000000          0.000000
# 40    2021-08-20     Friday  0.000000e+00      0.000000          0.000000
# 41    2021-08-21   Saturday  3.266641e+00     61.747289         58.480648
#
#     max_delivery_gap  ideal_supply  ideal_supply_old  ideal_ratio  \
# 35        865.310232   3315.585525       3977.579225          0.6
# 36        833.725035   2991.221603       3139.062677          0.6
# 37        709.641194   2666.101193       2749.904878          0.6
# 38        698.697626   2632.119127       2557.042849          0.6
# 39        695.398832   2621.007235       2441.547752          0.6
# 40        716.485842   2710.730024       2603.909369          0.6
# 41        693.207317   2618.683542       2596.870905          0.6
#
#     ideal_ratio_old  sd_ratio_pred  supply_pred  demand_pred
# 35         0.733286       0.501547  2771.538902  5525.975875
# 36         0.634705       0.626601  3123.836064  4985.369338
# 37         0.596848       0.705596  3135.318879  4443.501988
# 38         0.577796       0.692690  3038.738506  4386.865211
# 39         0.549184       0.670767  2930.143112  4368.345392
# 40         0.571722       0.614326  2775.452558  4517.883374
# 41         0.597389       0.591980  2583.678984  4364.472571

# %% [markdown]
# #### Comparing to old:

# %%
bt4[['delivery_gap_old', 'delivery_gap']].sum()
# Out:
# delivery_gap_old    52238.326878
# delivery_gap        69267.477447
# dtype: float64

# %%
# without covid growth factor
bt4[['delivery_gap_old', 'delivery_gap']].sum()
# Out:
# delivery_gap_old    52238.326878
# delivery_gap        46071.624081
# dtype: float64

# %%
ax = sns.distplot(bt4.delivery_gap_old, label='old', kde=False)
sns.distplot(bt4.delivery_gap, ax=ax, label='new', kde=False)
ax.legend()
ax.set_xlim(0,500)
# Out:
# /Users/sorenzeliger/.pyenv/versions/3.8.6/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 500.0)

# %%
ax = sns.distplot(bt4.delivery_gap_old, label='old', kde=False, bins=10)
sns.distplot(bt4.delivery_gap, ax=ax, label='new', kde=False, bins=10)
ax.legend()

# %%
sns.boxplot(x='dow', y='delivery_gap_old', data=bt4)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='delivery_gap_old'>

# %%
sns.boxplot(x='dow', y='delivery_gap', data=bt4)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='delivery_gap'>

# %%
ax = sns.distplot(bt4.loc[bt4.ideal_supply_old < 5000].ideal_supply_old, label='old', kde=False)
sns.distplot(bt4.loc[bt4.ideal_supply < 5000].ideal_supply, label='new', kde=False)
ax.legend()
# Out:
# /Users/sorenzeliger/.pyenv/versions/3.8.6/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/sorenzeliger/.pyenv/versions/3.8.6/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='dow', y='ideal_supply_old', data=bt4)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='ideal_supply_old'>

# %%
ax = sns.boxplot(x='dow', y='ideal_supply_old', data=bt4)
ax.set_ylim(0,10000)
# Out:
# (0.0, 10000.0)

# %%
sns.boxplot(x='dow', y='ideal_supply', data=bt4)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='ideal_supply'>

# %%
COLUMNS = ['zone_id', 'pred_for_date', 'forecast_date', 'horizon',
               'forecast_span', 'min_horizon', 'delivery_gap',
               'version', 'manual_adjustment', 'active', 'created_at', 'data']

bt4['created_at'] = datetime.utcnow()
bt4['min_horizon'] = 13
bt4['forecast_span'] = 7
bt4['manual_adjustment'] = None
bt4['version'] = 'v1.2'
bt4['data'] = None
bt4['active'] = 'Y'

# %%
# bt4.to_csv('./new_gaps_f_date_6_28.csv', index=None)
# bt4.to_csv('./new_gaps_f_date_7_19.csv', index=None)
# bt4.to_csv('./new_gaps_f_date_7_26.csv', index=None)
# bt4.to_csv('./new_gaps_f_date_8_02.csv', index=None)
bt4.to_csv('./new_gaps_f_date_8_02_no_covid_factor.csv', index=None)

# %% [markdown]
# ###### Largest Diffs

# %%
recent_metrics = pd.read_csv('./recent_metrics.csv')
recent_metrics['date'] = recent_metrics.date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())
recent_metrics = recent_metrics.set_index(recent_metrics.date)
recent_metrics['sd_ratio'] = recent_metrics.actual_shopper_visits / recent_metrics.total_demand

recent_metrics.head(2)
# Out:
#                   date  zone_id  total_demand  total_lost_demand  \
# date
# 2021-07-18  2021-07-18     1589     42.941489           1.941489
# 2021-06-15  2021-06-15      953     63.372668           2.372668
#
#             total_delivery_created  checkout_lost_demand  \
# date
# 2021-07-18                      41              1.357240
# 2021-06-15                      61              1.131179
#
#             capacity_lost_demand  pre_checkout_lost_demand  \
# date
# 2021-07-18              0.117997                  0.584249
# 2021-06-15              0.095538                  1.241489
#
#             supply_lost_demand  other_lost_demand  ...  \
# date                                               ...
# 2021-07-18            0.702246           1.239243  ...
# 2021-06-15            1.337026           1.035642  ...
#
#             time_based_capacity_availability  actual_shopper_visits  \
# date
# 2021-07-18                              85.5                     36
# 2021-06-15                              97.0                     83
#
#             actual_shopper_visits_full    avg_tta    p50_tta    p75_tta  \
# date
# 2021-07-18                          46  39.715789   7.166667  53.420833
# 2021-06-15                         104  26.628142  12.450000  38.416667
#
#                p90_tta  dels_completed  dels_completed_by_new_shoppers  \
# date
# 2021-07-18  126.033333              44                               0
# 2021-06-15   65.483333              70                               1
#
#             sd_ratio
# date
# 2021-07-18  0.838350
# 2021-06-15  1.309713
#
# [2 rows x 28 columns]

# %%
zone_lvl_gap_diff = bt4.groupby('zone_id').gap_diff.sum().reset_index()
zone_lvl_gap_diff.head(2)
# Out:
#    zone_id    gap_diff
# 0        1  419.560116
# 1       16  149.490680

# %%
sns.displot(zone_lvl_gap_diff.gap_diff)

# %%
zone_lvl_gap_diff.sort_values('gap_diff').head(5)
# Out:
#     zone_id     gap_diff
# 63      714 -1385.671870
# 4        32 -1206.166731
# 2        18 -1043.341369
# 3        27  -765.508855
# 64      783  -735.504525

# %%
zone_lvl_gap_diff.sort_values('gap_diff').tail(5)
# Out:
#     zone_id     gap_diff
# 15      104   642.268967
# 88     1002   724.755809
# 84      983   778.875592
# 32      225   796.086380
# 72      942  1482.702162

# %%
bt4.loc[bt4.zone_id == 714][['pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old', 'demand_pred', 'supply_pred', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow     gap_diff  delivery_gap  delivery_gap_old  \
# 91    2021-08-08     Sunday -1426.245750    668.197002       2094.442752
# 92    2021-08-09     Monday     0.000000      0.000000          0.000000
# 93    2021-08-10    Tuesday     0.000000      0.000000          0.000000
# 94    2021-08-11  Wednesday     0.000000      0.000000          0.000000
# 95    2021-08-12   Thursday     0.000000      0.000000          0.000000
# 96    2021-08-13     Friday     0.000000      0.000000          0.000000
# 97    2021-08-14   Saturday    40.573879     40.573879          0.000000
#
#     max_delivery_gap  ideal_supply  ideal_supply_old  ideal_ratio  \
# 91       2548.514764   3217.857402       4267.234296         0.63
# 92       2123.200394   2541.848079       2595.691403         0.63
# 93       1904.806905   2391.487020       2111.322186         0.63
# 94       1885.647967   2433.128602       1956.580079         0.63
# 95       1981.141697   2546.933899       1905.164303         0.63
# 96       2004.735692   2559.154376       2010.585914         0.63
# 97       2067.749195   2646.842413       2285.022830         0.63
#
#     ideal_ratio_old  demand_pred  supply_pred  sd_ratio_pred
# 91         0.760313  5107.710163  2723.518429       0.533217
# 92         0.570491  4034.679491  3079.975024       0.763375
# 93         0.483107  3796.011142  3033.223986       0.799056
# 94         0.454275  3862.108893  2892.462069       0.748933
# 95         0.431134  4042.752221  2759.710653       0.682632
# 96         0.454370  4062.149803  2744.678099       0.675671
# 97         0.501211  4201.337163  2616.825442       0.622855

# %%
recent_metrics.loc[recent_metrics.zone_id == 714][['total_demand', 'actual_shopper_visits']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 714][['time_based_capacity_availability']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 714].sd_ratio.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.scatterplot(x='sd_ratio', y='p50_tta', data=recent_metrics.loc[recent_metrics.zone_id == 714])
# Out:
# <AxesSubplot:xlabel='sd_ratio', ylabel='p50_tta'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 714][['p50_tta', 'avg_tta']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
bt4.loc[bt4.zone_id == 942][['pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old', 'demand_pred', 'supply_pred', 'sd_ratio_pred']]
# Out:
#    pred_for_date        dow      gap_diff  delivery_gap  delivery_gap_old  \
# 7     2021-08-08     Sunday -2.500542e-10    428.781197        428.781197
# 8     2021-08-09     Monday -1.500098e-10    414.810620        414.810620
# 9     2021-08-10    Tuesday  3.778818e+02    377.881801          0.000000
# 10    2021-08-11  Wednesday  3.623334e+02    362.333396          0.000000
# 11    2021-08-12   Thursday  3.651847e+02    365.184719          0.000000
# 12    2021-08-13     Friday  3.773022e+02    377.302247          0.000000
# 13    2021-08-14   Saturday -4.999947e-10    378.523419        378.523419
#
#     max_delivery_gap  ideal_supply  ideal_supply_old  ideal_ratio  \
# 7         428.781197   5740.763919       7086.345144         0.65
# 8         414.810620   5476.835193       5020.468693         0.65
# 9         377.881801   5044.632240       4021.885913         0.65
# 10        362.333396   5031.238915       3562.556893         0.65
# 11        365.184719   5013.137824       3495.071609         0.65
# 12        377.302247   5107.285921       3895.442198         0.65
# 13        378.523419   5145.062421       4733.593473         0.65
#
#     ideal_ratio_old  demand_pred  supply_pred  sd_ratio_pred
# 7          0.807207  8831.944490  4151.474049       0.470052
# 8          0.593593  8425.900296  4697.442467       0.557500
# 9          0.499429  7760.972678  4701.722033       0.605816
# 10         0.460091  7740.367561  4458.910058       0.576059
# 11         0.452509  7712.519729  4501.034935       0.583601
# 12         0.485716  7857.362955  4184.592307       0.532570
# 13         0.588557  7915.480647  3977.140763       0.502451

# %%
recent_metrics.loc[recent_metrics.zone_id == 942][['total_demand', 'actual_shopper_visits']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 942][['time_based_capacity_availability']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 942].sd_ratio.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.scatterplot(x='sd_ratio', y='p50_tta', data=recent_metrics.loc[recent_metrics.zone_id == 942])
# Out:
# <AxesSubplot:xlabel='sd_ratio', ylabel='p50_tta'>

# %%
recent_metrics.loc[recent_metrics.zone_id == 942][['p50_tta', 'avg_tta']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Backwards-Looking:

# %%
# [] pull in actual daily demand and supply
# [] pull in metrics for the pred_for_dates
# [] look at how we'd shape up with perfect demand and supply forecasts

# [] look at % hitting max gap
# [] document some aggregate analysis and case studies 

# [] more test dates, repeat ^

# [] back to hierarchical forecast work
    # [] maybe can have it not run so long, since seemed to overfit

# %%
f_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-1f6c4f1b6ea1> in <module>
# ----> 1 f_date
#
# NameError: name 'f_date' is not defined

# %%
# metrics = pd.read_csv('./metrics_fdate_04_26_21.csv')
metrics = pd.read_csv('./metrics_fdate_06_28_21.csv')
metrics['date'] = metrics.date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').date())

metrics.head(2)
# Out:
#          date  zone_id  total_demand  total_lost_demand  \
# 0  2021-07-09     1939      4.047572           0.047572
# 1  2021-07-17      757    368.382279          10.382279
#
#    total_delivery_created  checkout_lost_demand  capacity_lost_demand  \
# 0                       4              0.046637              0.037626
# 1                     358              6.433553              0.055610
#
#    pre_checkout_lost_demand  supply_lost_demand  other_lost_demand  ...  \
# 0                  0.000936            0.038561           0.009011  ...
# 1                  3.948726            4.004336           6.377943  ...
#
#    solvable_supply_ld_pct_post_inc  time_based_capacity_availability  \
# 0                         0.952702                             100.0
# 1                         0.616342                             100.0
#
#    actual_shopper_visits  actual_shopper_visits_full    avg_tta    p50_tta  \
# 0                      6                           6  25.556667  16.950000
# 1                    285                         349   4.061692   0.433333
#
#      p75_tta  p90_tta  dels_completed  dels_completed_by_new_shoppers
# 0  46.750000    53.62               4                               0
# 1   1.833333     6.75             352                              14
#
# [2 rows x 27 columns]

# %%
list(metrics)
# Out:
# ['date',
#  'zone_id',
#  'total_demand',
#  'total_lost_demand',
#  'total_delivery_created',
#  'checkout_lost_demand',
#  'capacity_lost_demand',
#  'pre_checkout_lost_demand',
#  'supply_lost_demand',
#  'other_lost_demand',
#  'negative_capacity_supply_lost_demand',
#  'solvable_supply_lost_demand_post_inc',
#  'solvable_supply_lost_demand_pre_inc',
#  'total_other_ld_pct',
#  'total_ld_pct',
#  'supply_ld_pct',
#  'solvable_supply_ld_pct_pre_inc',
#  'solvable_supply_ld_pct_post_inc',
#  'time_based_capacity_availability',
#  'actual_shopper_visits',
#  'actual_shopper_visits_full',
#  'avg_tta',
#  'p50_tta',
#  'p75_tta',
#  'p90_tta']

# %%
bt5 = bt4.merge(metrics,
                left_on=['zone_id', 'pred_for_date'],
                right_on=['zone_id', 'date'])
bt5.shape
# Out:
# (630, 62)

# %%
[['pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old', 'sd_ratio_pred']]

# %%
bt5.loc[bt5.zone_id == 103][['pred_for_date', 'dow', 'supply_pred', 'actual_shopper_visits', 'demand_pred', 'total_demand']]
# Out:
#     pred_for_date        dow  supply_pred  actual_shopper_visits  demand_pred  \
# 336    2021-07-11     Sunday   921.851038                   1120  1712.403444
# 337    2021-07-12     Monday  1036.373088                   1264  1628.691674
# 338    2021-07-13    Tuesday  1047.280421                   1305  1453.726273
# 339    2021-07-14  Wednesday  1067.920541                   1243  1453.932719
# 340    2021-07-15   Thursday  1089.958539                   1213  1517.977374
# 341    2021-07-16     Friday  1102.213477                   1140  1614.610035
# 342    2021-07-17   Saturday  1055.832549                   1044  1462.778635
#
#      total_demand
# 336   1663.291729
# 337   1581.709354
# 338   1455.984212
# 339   1412.314549
# 340   1495.099023
# 341   1537.373078
# 342   1516.710230

# %%
bt5.loc[bt5.zone_id == 1][['pred_for_date', 'dow', 'supply_pred', 'actual_shopper_visits', 'demand_pred', 'total_demand']]
# Out:
#     pred_for_date        dow  supply_pred  actual_shopper_visits  demand_pred  \
# 238    2021-05-09     Sunday  1209.305673                   1188  4836.241396
# 239    2021-05-10     Monday  1342.589648                   1383  4248.237004
# 240    2021-05-11    Tuesday  1354.594529                   1436  3889.057458
# 241    2021-05-12  Wednesday  1349.259840                   1417  3801.263897
# 242    2021-05-13   Thursday  1323.484894                   1364  3672.532889
# 243    2021-05-14     Friday  1301.874061                   1404  3720.868670
# 244    2021-05-15   Saturday  1255.475052                   1298  3849.737671
#
#      total_demand
# 238   4137.113552
# 239   4322.666790
# 240   3782.802797
# 241   3539.149618
# 242   3423.184428
# 243   3576.268500
# 244   3679.965251

# %% [markdown]
# #### Pre-Incentive Supply LD

# %%
# before ideal ratio updates
sns.regplot(x='delivery_gap', y='solvable_supply_lost_demand_pre_inc', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='solvable_supply_lost_demand_pre_inc'>

# %%
# after ideal ratio updates
sns.regplot(x='delivery_gap', y='solvable_supply_lost_demand_pre_inc', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='solvable_supply_lost_demand_pre_inc'>

# %%
sns.regplot(x='delivery_gap_old', y='solvable_supply_lost_demand_pre_inc', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap_old', ylabel='solvable_supply_lost_demand_pre_inc'>

# %% [markdown]
# #### Mean TTA

# %%
sns.regplot(x='delivery_gap', y='avg_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='avg_tta'>

# %%
sns.regplot(x='delivery_gap', y='avg_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='avg_tta'>

# %%
sns.regplot(x='delivery_gap_old', y='avg_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap_old', ylabel='avg_tta'>

# %% [markdown]
# #### Median TTA

# %%
sns.regplot(x='delivery_gap', y='p50_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='p50_tta'>

# %%
sns.regplot(x='delivery_gap_old', y='p50_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap_old', ylabel='p50_tta'>

# %% [markdown]
# #### Capacity Availability

# %%
sns.regplot(x='delivery_gap', y='time_based_capacity_availability', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap', ylabel='time_based_capacity_availability'>

# %%
sns.regplot(x='delivery_gap_old', y='time_based_capacity_availability', data=bt5)
# Out:
# <AxesSubplot:xlabel='delivery_gap_old', ylabel='time_based_capacity_availability'>

# %%
bt5['ideal_supply_p'] = bt5.total_demand_new * bt5.ideal_ratio
bt5['supply_deficit_p'] = bt5.ideal_supply - bt5.actual_shopper_visits
bt5['supply_deficit_non_neg_p'] = np.maximum(bt5.supply_deficit_p, 0)
bt5['delivery_gap_pre_cap_p'] = bt5.supply_deficit_non_neg_p * bt5.median_dps
bt5['delivery_gap_p'] = np.minimum(bt5.delivery_gap_pre_cap_p, bt5.max_delivery_gap)

# %%
sns.scatterplot(x='demand_pred', y='total_demand', data=bt5)
# Out:
# <AxesSubplot:xlabel='demand_pred', ylabel='total_demand'>

# %%
sns.scatterplot(x='demand_pred', y='total_demand', data=bt5)
# Out:
# <AxesSubplot:xlabel='demand_pred', ylabel='total_demand'>

# %%
sns.distplot(bt5.demand_pred - bt5.total_demand)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.scatterplot(x='supply_pred', y='actual_shopper_visits', data=bt5)
# Out:
# <AxesSubplot:xlabel='supply_pred', ylabel='actual_shopper_visits'>

# %%
sns.distplot(bt5.supply_pred - bt5.actual_shopper_visits)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print(f'Old Gap: {round(bt5.delivery_gap_old.sum())}')
print(f'New Gap: {round(bt5.delivery_gap.sum())}')
# print(f'New Gap w/ Perfect Supply & Demand Forecasts: {round(bt5.delivery_gap_p.sum())}')
# Out:
# Old Gap: 156658
# New Gap: 172367

# %%
print(f'Solvable Supply LD Pre-Incentives: {bt5.solvable_supply_lost_demand_pre_inc.sum()}')
print(f'Solvable Supply LD Post-Incentives: {bt5.solvable_supply_lost_demand_post_inc.sum()}')
# Out:
# Solvable Supply LD Pre-Incentives: 105075.900560592
# Solvable Supply LD Post-Incentives: 42877.916304472004

# %%
sns.boxplot(x='dow', y='delivery_gap', data=bt5)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='delivery_gap'>

# %%
sns.boxplot(x='dow', y='delivery_gap_old', data=bt5)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='delivery_gap_old'>

# %%
sns.boxplot(x='dow', y='p50_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='p50_tta'>

# %%
sns.boxplot(x='dow', y='avg_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='dow', ylabel='avg_tta'>

# %%
bt5.sort_values('gap_diff')[['zone_id', 'pred_for_date', 'dow', 'gap_diff', 'delivery_gap', 'delivery_gap_old', 'ideal_supply', 'ideal_supply_old']].head(10)
# Out:
#      zone_id pred_for_date        dow    gap_diff  delivery_gap  \
# 576       27    2021-05-11    Tuesday -641.381709    123.458164
# 579       27    2021-05-14     Friday -632.146586    100.348665
# 168      973    2021-05-09     Sunday -585.231718    747.698898
# 577       27    2021-05-12  Wednesday -551.789572    226.318586
# 588      183    2021-05-09     Sunday -493.125775    277.877019
# 624       87    2021-05-10     Monday -491.808364     36.148848
# 629       87    2021-05-15   Saturday -442.612544      0.000000
# 575       27    2021-05-10     Monday -431.236564    426.984699
# 443      713    2021-05-11    Tuesday -426.259929    144.400790
# 623       87    2021-05-09     Sunday -423.277058    256.459098
#
#      delivery_gap_old  ideal_supply  ideal_supply_old
# 576        764.839874   1763.769053      15586.326229
# 579        732.495250   1712.270326      15428.736659
# 168       1332.930616   3810.538061       4104.418800
# 577        778.108158   1846.704546      14613.214525
# 588        771.002794   1394.051156       1599.396055
# 624        527.957212   1611.164928       1912.597790
# 629        442.612544   1475.727584       1751.821471
# 575        858.221263   1945.605553      20633.508017
# 443        570.660719   1602.657990       1881.034475
# 623        679.736156   1645.806117       1845.180000

# %%
zone_agg_gap_diffs = bt5.groupby('zone_id').gap_diff.sum().reset_index()

# %%
zone_agg_gap_diffs.sort_values('gap_diff').head()
# Out:
#     zone_id     gap_diff
# 3        27 -3393.595511
# 12       87 -2675.984487
# 62      713 -2012.324335
# 40      392 -1743.238761
# 77      973 -1332.930616

# %%
zone_agg_gap_diffs.sort_values('gap_diff').tail()
# Out:
#     zone_id     gap_diff
# 16      131  2013.641644
# 66      786  2193.121754
# 73      943  3398.811595
# 63      714  3534.299529
# 65      785  4862.198630

# %%
zone_agg_gap_diffs.loc[zone_agg_gap_diffs.gap_diff > 0].shape
# Out:
# (58, 2)

# %%
sns.distplot(bt5.loc[bt5.gap_diff > 0].solvable_supply_ld_pct_pre_inc)
# Out:
# <AxesSubplot:xlabel='solvable_supply_ld_pct_pre_inc', ylabel='Density'>

# %%
sns.distplot(bt5.loc[bt5.gap_diff < 0].solvable_supply_ld_pct_pre_inc)
# Out:
# <AxesSubplot:xlabel='solvable_supply_ld_pct_pre_inc', ylabel='Density'>

# %%
sns.distplot(bt5.loc[bt5.gap_diff > 0].p50_tta)
# Out:
# <AxesSubplot:xlabel='p50_tta', ylabel='Density'>

# %%
bt5.loc[bt5.gap_diff > 0].p50_tta.describe()
# Out:
# count    280.000000
# mean       6.480982
# std        5.777056
# min        0.500000
# 25%        4.279166
# 50%        4.866667
# 75%        6.072917
# max       41.625000
# Name: p50_tta, dtype: float64

# %%
ax = sns.distplot(bt5.loc[bt5.gap_diff < 0].p50_tta, label='smaller gaps')
sns.distplot(bt5.loc[bt5.gap_diff > 0].p50_tta, label='larger gaps')
ax.legend(loc='best')

# %%
ax = sns.distplot(bt5.loc[bt5.gap_diff < 0].p50_tta, label='smaller gaps')
sns.distplot(bt5.loc[bt5.gap_diff > 0].p50_tta, label='larger gaps')
ax.legend(loc='best')

# %%
bt5['gap_diff'] = round(bt5.gap_diff)

# %%
sns.distplot(bt5.gap_diff)
# Out:
# <AxesSubplot:xlabel='gap_diff', ylabel='Density'>

# %%
sns.scatterplot(x='gap_diff', y='p50_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='gap_diff', ylabel='p50_tta'>

# %%
sns.scatterplot(x='gap_diff', y='avg_tta', data=bt5)
# Out:
# <AxesSubplot:xlabel='gap_diff', ylabel='avg_tta'>

# %% [markdown]
# ### Zone Case Studies

# %%
### Before ideal ratio updates

bt5.loc[bt5.zone_id == 942][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old']]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 147    2021-05-09     Sunday   2376.624391       2376.624391
# 148    2021-05-10     Monday   1947.512272       2239.394356
# 149    2021-05-11    Tuesday    685.163875       1978.723577
# 150    2021-05-12  Wednesday      0.000000       1456.950416
# 151    2021-05-13   Thursday    395.073745       1926.685502
# 152    2021-05-14     Friday    941.726611       1919.506171
# 153    2021-05-15   Saturday    897.804809       1972.547796
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 147       2376.624391                           756.157306
# 148       2239.394356                           569.166953
# 149       1978.723577                           334.784996
# 150       1976.858470                           176.718758
# 151       1926.685502                           405.881905
# 152       1919.506171                           303.500388
# 153       1972.547796                           522.349377
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 147                            187.894076                        9.751183
# 148                            144.675462                        6.786620
# 149                            131.108096                        4.438697
# 150                            144.387731                        2.458736
# 151                            136.146238                        5.513472
# 152                            102.957364                        4.266649
# 153                            136.573106                        7.090151
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 147                         2.423027  24.739088  12.616667
# 148                         1.725078  10.144966   6.283333
# 149                         1.738277   6.406623   5.133333
# 150                         2.008906   6.287254   5.075000
# 151                         1.849401   6.036762   4.833333
# 152                         1.447388   7.068168   5.333333
# 153                         1.853786   7.220629   5.583333
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 147                             98.52   5126.082151       7631.333643
# 148                            100.00   4955.677095       7049.191093
# 149                            100.00   4302.647668       5128.478100
# 150                            100.00   3748.849744       4572.116593
# 151                            100.00   4024.345121       5543.084532
# 152                            100.00   4166.458929       5010.706517
# 153                            100.00   3994.249202       6502.097574
#
#      ideal_ratio  ideal_ratio_old
# 147     0.555673         0.831208
# 148     0.562393         0.672035
# 149     0.529206         0.529899
# 150     0.461387         0.472716
# 151     0.503931         0.583100
# 152     0.525579         0.530989
# 153     0.494416         0.676125

# %%
### After ideal ratio updates

bt5.loc[bt5.zone_id == 942][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
#     'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'supply_pred', 'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 147    2021-05-09     Sunday   2376.624391       2376.624391
# 148    2021-05-10     Monday   2239.394356       2239.394356
# 149    2021-05-11    Tuesday   1978.723577       1978.723577
# 150    2021-05-12  Wednesday   1976.858470       1456.950416
# 151    2021-05-13   Thursday   1926.685502       1926.685502
# 152    2021-05-14     Friday   1919.506171       1919.506171
# 153    2021-05-15   Saturday   1972.547796       1972.547796
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 147       2376.624391                           756.157306
# 148       2239.394356                           569.166953
# 149       1978.723577                           334.784996
# 150       1976.858470                           176.718758
# 151       1926.685502                           405.881905
# 152       1919.506171                           303.500388
# 153       1972.547796                           522.349377
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 147                            187.894076                        9.751183
# 148                            144.675462                        6.786620
# 149                            131.108096                        4.438697
# 150                            144.387731                        2.458736
# 151                            136.146238                        5.513472
# 152                            102.957364                        4.266649
# 153                            136.573106                        7.090151
#
#      solvable_supply_ld_pct_post_inc    avg_tta  ...  \
# 147                         2.423027  24.739088  ...
# 148                         1.725078  10.144966  ...
# 149                         1.738277   6.406623  ...
# 150                         2.008906   6.287254  ...
# 151                         1.849401   6.036762  ...
# 152                         1.447388   7.068168  ...
# 153                         1.853786   7.220629  ...
#
#      time_based_capacity_availability  supply_pred  ideal_supply  \
# 147                             98.52  3531.384094   5927.641273
# 148                            100.00  3928.154016   5665.377207
# 149                            100.00  3941.149717   5090.979591
# 150                            100.00  3867.859106   5019.328121
# 151                            100.00  3815.901047   5048.224232
# 152                            100.00  3669.596423   5057.549650
# 153                            100.00  3520.560191   5088.645931
#
#      ideal_supply_old  ideal_ratio  ideal_ratio_old  demand_pred  \
# 147       7631.333643         0.65         0.831208  9119.448113
# 148       7049.191093         0.65         0.672035  8715.964933
# 149       5128.478100         0.65         0.529899  7832.276293
# 150       4572.116593         0.65         0.472716  7722.043264
# 151       5543.084532         0.65         0.583100  7766.498818
# 152       5010.706517         0.65         0.530989  7780.845616
# 153       6502.097574         0.65         0.676125  7828.686047
#
#      total_demand  supply_pred  actual_shopper_visits
# 147   7754.518378  3531.384094                   3694
# 148   8386.604332  3928.154016                   4573
# 149   7542.415920  3941.149717                   4489
# 150   7187.382278  3867.859106                   4529
# 151   7361.638926  3815.901047                   4454
# 152   7113.320366  3669.596423                   4260
# 153   7367.253263  3520.560191                   3980
#
# [7 rows x 21 columns]

# %% [markdown]
# #### Smaller Gap Zones

# %%
# Underforecasted supply
bt5.loc[bt5.zone_id == 713][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'

]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 441    2021-05-09     Sunday    782.942006        803.824093
# 442    2021-05-10     Monday    326.574708        688.416941
# 443    2021-05-11    Tuesday     65.782546        570.660719
# 444    2021-05-12  Wednesday    121.220746        610.267456
# 445    2021-05-13   Thursday    228.322027        529.437985
# 446    2021-05-14     Friday    429.007837        411.451936
# 447    2021-05-15   Saturday    375.283145        727.398219
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 441        803.824093                           706.969467
# 442        688.416941                           243.541262
# 443        570.660719                           163.893023
# 444        610.267456                           164.375363
# 445        601.765967                           170.505479
# 446        622.225926                            76.499534
# 447        727.398219                           193.186795
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 441                            551.240650                       25.192310
# 442                             38.647755                        8.994447
# 443                             32.091991                        6.932203
# 444                             29.696508                        7.213581
# 445                             30.906623                        7.448731
# 446                             30.913241                        3.099323
# 447                             31.048077                        7.869913
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 441                        19.643034  47.763922  28.500000
# 442                         1.427336  17.865592   7.183333
# 443                         1.357399   8.725431   4.716667
# 444                         1.303226   8.641516   4.400000
# 445                         1.350192   6.737668   4.300000
# 446                         1.252427   9.755008   4.883333
# 447                         1.264816  12.153950   5.716667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 441                              5.22   2014.657771       2709.571581
# 442                            100.00   1754.849047       2178.924922
# 443                            100.00   1550.903080       1881.034475
# 444                            100.00   1541.551539       1898.120190
# 445                            100.00   1568.293246       1801.280153
# 446                            100.00   1677.099319       1689.247419
# 447                            100.00   1686.005681       2182.164566
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 441          0.7         0.955244  2878.082530   2806.290734  1499.241872
# 442          0.7         0.874442  2506.927209   2707.684642  1539.862757
# 443          0.7         0.849096  2215.575829   2364.227013  1507.597995
# 444          0.7         0.810037  2202.216484   2278.692941  1461.751120
# 445          0.7         0.776532  2240.418922   2289.053931  1417.987346
# 446          0.7         0.731697  2395.856171   2468.266086  1394.680624
# 447          0.7         0.803892  2408.579545   2454.751372  1438.954306
#
#      actual_shopper_visits
# 441                   1408
# 442                   1886
# 443                   1845
# 444                   1857
# 445                   1843
# 446                   1763
# 447                   1624

# %%
# most of these days had good p50 TTA -- maybe should use avg TTA?
bt5.loc[bt5.zone_id == 392][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'

]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 616    2021-05-09     Sunday    413.852094       1058.337008
# 617    2021-05-10     Monday    193.557773        282.628427
# 618    2021-05-11    Tuesday      0.000000        225.357838
# 619    2021-05-12  Wednesday      0.000000        281.313855
# 620    2021-05-13   Thursday      3.588522          0.000000
# 621    2021-05-14     Friday      3.942268        366.288709
# 622    2021-05-15   Saturday     93.976349        238.229930
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 616       1058.337008                           610.860677
# 617        818.644901                           313.956723
# 618        732.239628                           195.900221
# 619        707.124476                           187.300157
# 620        697.397681                           191.112073
# 621        714.030449                           107.848744
# 622        771.186144                           218.552009
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 616                            409.942013                       21.144042
# 617                             75.445556                        9.761726
# 618                             48.706735                        7.793116
# 619                             55.938940                        7.955170
# 620                             50.537893                        7.799038
# 621                             43.006595                        4.378215
# 622                             58.563912                        8.364111
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 616                        14.189538  47.476030  14.783333
# 617                         2.345797  14.456565   4.091666
# 618                         1.937605   7.699653   1.466667
# 619                         2.375886   7.704695   1.166667
# 620                         2.062386   7.711007   1.233333
# 621                         1.745891   8.820868   1.800000
# 622                         2.241275   9.547856   2.191667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 616                              31.6    759.964996       1175.142453
# 617                             100.0    725.882567        805.645164
# 618                             100.0    620.693936        735.304319
# 619                             100.0    581.189025        755.330038
# 620                             100.0    586.547092        588.893762
# 621                             100.0    592.114302        788.000476
# 622                             100.0    607.731066        667.689417
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 616         0.23         0.296442  3304.195634   2889.044057   553.038949
# 617         0.23         0.269911  3156.011160   3216.200861   629.103680
# 618         0.23         0.278843  2698.669285   2513.759693   624.349081
# 619         0.23         0.281807  2526.908805   2354.445606   608.894664
# 620         0.23         0.234883  2550.204747   2450.457069   584.752831
# 621         0.23         0.288391  2574.410007   2463.304102   590.143168
# 622         0.23         0.241973  2642.308984   2612.973535   560.742892
#
#      actual_shopper_visits
# 616                    475
# 617                    699
# 618                    649
# 619                    644
# 620                    616
# 621                    591
# 622                    534

# %%
# most of these days had good p50 TTA -- maybe should use avg TTA?
bt5.loc[bt5.zone_id == 90][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'

]]
# Out:
#    pred_for_date        dow  delivery_gap  delivery_gap_old  max_delivery_gap  \
# 28    2021-05-09     Sunday    301.382997        414.681169        414.681169
# 29    2021-05-10     Monday    152.968589        406.169854        406.169854
# 30    2021-05-11    Tuesday      0.000000        166.877206        326.987102
# 31    2021-05-12  Wednesday      0.000000         99.211402        328.536518
# 32    2021-05-13   Thursday      0.000000        177.605913        325.227937
# 33    2021-05-14     Friday      0.000000        182.579513        321.013460
# 34    2021-05-15   Saturday      0.000000        258.904306        326.928301
#
#     solvable_supply_lost_demand_pre_inc  solvable_supply_lost_demand_post_inc  \
# 28                           278.411689                            198.814294
# 29                           132.986047                             23.609268
# 30                            89.108338                             29.614465
# 31                            57.299869                             10.980654
# 32                            93.750280                             15.558407
# 33                            69.530296                             16.001381
# 34                            94.491123                             16.636750
#
#     solvable_supply_ld_pct_pre_inc  solvable_supply_ld_pct_post_inc  \
# 28                       19.557972                        13.966384
# 29                        7.952617                         1.411843
# 30                        6.432450                         2.137775
# 31                        4.523952                         0.866947
# 32                        7.258391                         1.204572
# 33                        5.304665                         1.220791
# 34                        7.520316                         1.324078
#
#       avg_tta    p50_tta  time_based_capacity_availability  ideal_supply  \
# 28  39.893870  21.483334                             13.33   1400.292741
# 29  21.482306   9.133333                            100.00   1383.988700
# 30  29.757111  10.650000                             91.08   1142.722964
# 31  12.011857   4.966667                            100.00   1111.668532
# 32   9.002090   4.466667                            100.00   1120.408432
# 33  10.216908   4.525000                            100.00   1147.977798
# 34  11.678588   5.383333                            100.00   1109.107615
#
#     ideal_supply_old  ideal_ratio  ideal_ratio_old  demand_pred  total_demand  \
# 28       1966.072780          1.0         1.300133  1400.292741   1423.520216
# 29       1816.671634          1.0         1.167137  1383.988700   1672.229943
# 30       1533.907341          1.0         1.120786  1142.722964   1385.293928
# 31       1506.995813          1.0         1.109732  1111.668532   1266.588790
# 32       1534.243939          1.0         1.109191  1120.408432   1291.612435
# 33       1534.158611          1.0         1.132155  1147.977798   1310.738654
# 34       1536.104387          1.0         1.132607  1109.107615   1256.478071
#
#     supply_pred  actual_shopper_visits
# 28  1081.340920                   1122
# 29  1222.102958                   1486
# 30  1245.756888                   1362
# 31  1277.875948                   1449
# 32  1233.527518                   1452
# 33  1230.625698                   1395
# 34  1231.142622                   1280

# %%
# underforecast demand a bit
bt5.loc[bt5.zone_id == 87][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
#     'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old', 'sd_ratio_pred',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'

]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 623    2021-05-09     Sunday    234.803205        679.736156
# 624    2021-05-10     Monday    105.846390        527.957212
# 625    2021-05-11    Tuesday      0.000000        342.431210
# 626    2021-05-12  Wednesday      0.000000        318.884264
# 627    2021-05-13   Thursday      0.000000        353.250008
# 628    2021-05-14     Friday    113.337887        465.100574
# 629    2021-05-15   Saturday      0.000000        442.612544
#
#      max_delivery_gap  solvable_supply_ld_pct_pre_inc  \
# 623        711.376993                       18.133121
# 624        768.676021                        8.098784
# 625        740.047362                        8.613143
# 626        689.792950                       11.139342
# 627        697.535448                        8.209559
# 628        711.488441                        5.520481
# 629        647.532999                        8.970003
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 623                        13.306401  95.617228  69.516666
# 624                         2.682911  26.604186  12.191667
# 625                         3.382861  14.645217   4.883333
# 626                         6.058164   8.507462   2.133333
# 627                         3.081680   7.412338   1.983333
# 628                         2.395528  10.740199   3.958334
# 629                         4.619090  10.885296   4.508333
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 623                              0.37   1632.294521       1845.180000
# 624                            100.00   1654.650783       1912.597790
# 625                            100.00   1530.365242       1879.189903
# 626                            100.00   1521.119199       1833.490791
# 627                            100.00   1584.124667       1865.592000
# 628                            100.00   1624.755148       1883.088000
# 629                            100.00   1431.342721       1751.821471
#
#      ideal_ratio  ideal_ratio_old  sd_ratio_pred  demand_pred  total_demand  \
# 623          0.6              0.6       0.546150  2720.490868   2622.828962
# 624          0.6              0.6       0.576053  2757.751305   2963.296822
# 625          0.6              0.6       0.644442  2550.608737   2738.436745
# 626          0.6              0.6       0.641513  2535.198664   2739.009302
# 627          0.6              0.6       0.609274  2640.207778   2841.409362
# 628          0.6              0.6       0.573886  2707.925247   2896.101429
# 629          0.6              0.6       0.632785  2385.571201   2668.397351
#
#      supply_pred  actual_shopper_visits
# 623  1485.795549                   1306
# 624  1588.610853                   1778
# 625  1643.720562                   1835
# 626  1626.362534                   1737
# 627  1608.610545                   1774
# 628  1554.041105                   1783
# 629  1509.554190                   1619

# %%
# previously hitting guardrail every day. now gaps better aligned with solvable_supply_ld_pct_pre_inc
bt5.loc[bt5.zone_id == 27][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
#     'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old', 'sd_ratio_pred',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'

]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 574    2021-05-09     Sunday    966.097267        966.097267
# 575    2021-05-10     Monday    426.984699        858.221263
# 576    2021-05-11    Tuesday    123.458164        764.839874
# 577    2021-05-12  Wednesday    226.318586        778.108158
# 578    2021-05-13   Thursday    410.395227        794.434373
# 579    2021-05-14     Friday    100.348665        732.495250
# 580    2021-05-15   Saturday    341.386913        732.545288
#
#      max_delivery_gap  solvable_supply_ld_pct_pre_inc  \
# 574        966.097267                       14.614923
# 575        858.221263                       13.681583
# 576        764.839874                        8.232843
# 577        778.108158                        7.968669
# 578        794.434373                        8.284259
# 579        732.495250                        6.420456
# 580        732.545288                        8.994807
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 574                         6.846450  34.101048  11.816667
# 575                         7.316581  35.288691  10.608333
# 576                         2.398458  18.518517   5.800000
# 577                         2.869237  12.813522   4.433333
# 578                         3.087951  19.753163   5.133333
# 579                         2.077559  18.739882   5.600000
# 580                         3.266029  14.004982   4.600000
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 574                             64.31   2252.431966      18045.987250
# 575                             66.04   1945.605553      20633.508017
# 576                            100.00   1763.769053      15586.326229
# 577                            100.00   1846.704546      14613.214525
# 578                             95.17   1897.284099      14209.403794
# 579                            100.00   1712.270326      15428.736659
# 580                            100.00   1800.329942      12074.681410
#
#      ideal_ratio  ideal_ratio_old  sd_ratio_pred  demand_pred  total_demand  \
# 574          0.6         4.657053       0.404609  3754.053277   2952.016177
# 575          0.6         5.716207       0.520078  3242.675922   3683.021166
# 576          0.6         4.763122       0.574509  2939.615088   2820.428999
# 577          0.6         4.265187       0.555369  3077.840909   2751.439042
# 578          0.6         4.036762       0.521227  3162.140165   2575.061518
# 579          0.6         4.856772       0.578657  2853.783876   2608.432136
# 580          0.6         3.615041       0.530944  3000.549904   2533.076770
#
#      supply_pred  actual_shopper_visits
# 574  1518.925032                   1375
# 575  1686.444253                   1817
# 576  1688.835271                   1811
# 577  1709.338923                   1800
# 578  1648.191892                   1620
# 579  1651.363013                   1704
# 580  1593.122807                   1539

# %% [markdown]
# ##### Larger Gaps

# %%
### Old version was likely misled by capacity staying on. Avg TTA's are high

bt5.loc[bt5.zone_id == 786][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand'
#     'demand_dow_dist'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 595    2021-05-09     Sunday    546.741733        546.741733
# 596    2021-05-10     Monday    482.750693         68.949767
# 597    2021-05-11    Tuesday    314.731908          0.000000
# 598    2021-05-12  Wednesday    301.294030          0.000000
# 599    2021-05-13   Thursday    410.005679          0.000000
# 600    2021-05-14     Friday    422.093569          0.000000
# 601    2021-05-15   Saturday    457.761242        126.565599
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 595        546.741733                           415.113204
# 596        482.750693                            82.323964
# 597        429.757027                           169.695554
# 598        423.662481                            67.402402
# 599        421.236027                            67.052771
# 600        422.093569                            66.345299
# 601        457.761242                           185.954368
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 595                            190.466087                       14.113083
# 596                             43.386461                        2.510076
# 597                             21.334508                        5.611354
# 598                             56.624456                        2.135748
# 599                             37.190794                        2.532724
# 600                             33.575664                        2.360875
# 601                             41.217748                        6.873585
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 595                         6.475495  45.664420  24.033333
# 596                         1.322863  15.877920   7.150000
# 597                         0.705472  13.278823   5.416667
# 598                         1.794233  34.711028  15.900000
# 599                         1.404774  17.229438   6.700000
# 600                         1.194778  13.255088   5.333333
# 601                         1.523566  13.935922   6.116667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 595                             71.54   2188.920172       2146.039354
# 596                            100.00   1980.467768       1688.608761
# 597                            100.00   1767.214980       1406.667011
# 598                             93.31   1723.739206       1436.475715
# 599                            100.00   1739.037990       1290.167142
# 600                            100.00   1770.923815       1225.625377
# 601                            100.00   1766.679908       1529.352645
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand
# 595          0.6         0.536861  3648.200286   2941.336133
# 596          0.6         0.468006  3300.779614   3279.740046
# 597          0.6         0.436287  2945.358300   3024.146274
# 598          0.6         0.441480  2872.898677   3155.914749
# 599          0.6         0.402257  2898.396649   2647.456962
# 600          0.6         0.386340  2951.539692   2810.200084
# 601          0.6         0.429602  2944.466514   2705.347673

# %%
### Old ideal ratios hit min value. Looks good to have larger gap here

bt5.loc[bt5.zone_id == 76][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 301    2021-05-09     Sunday    493.283230               0.0
# 302    2021-05-10     Monday    331.986972               0.0
# 303    2021-05-11    Tuesday    120.326901               0.0
# 304    2021-05-12  Wednesday     43.639129               0.0
# 305    2021-05-13   Thursday    172.591602               0.0
# 306    2021-05-14     Friday    202.205913               0.0
# 307    2021-05-15   Saturday    162.823195               0.0
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 301        493.283230                           178.829515
# 302        441.856185                            84.633230
# 303        415.989848                            63.737549
# 304        410.129521                            53.736299
# 305        405.889596                            65.834925
# 306        425.270538                            63.752363
# 307        434.372512                            90.384146
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 301                            114.933667                       12.424199
# 302                             22.457372                        4.922536
# 303                             20.652949                        4.172215
# 304                             19.382780                        3.754644
# 305                             25.413866                        4.509003
# 306                             18.451634                        4.131943
# 307                             28.274257                        6.262221
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 301                         7.985028  45.183333  18.775000
# 302                         1.306192  13.974369   6.800000
# 303                         1.351928   9.579318   5.191667
# 304                         1.354307   7.149434   4.583333
# 305                         1.740584   9.824746   4.933333
# 306                         1.195894  14.964904   6.533333
# 307                         1.958968  14.511790   6.966667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 301                             52.59   1429.231322        209.202000
# 302                            100.00   1372.318135        195.976904
# 303                            100.00   1241.713258        187.226946
# 304                            100.00   1184.938106        181.728495
# 305                            100.00   1221.649063        178.383161
# 306                            100.00   1255.438004        183.899612
# 307                            100.00   1196.179358        187.357847
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 301          0.8              0.1  1786.539153   1439.364549   989.314527
# 302          0.8              0.1  1715.397669   1719.301541  1128.159710
# 303          0.8              0.1  1552.141573   1527.666769  1153.219344
# 304          0.8              0.1  1481.172632   1431.195470  1152.843891
# 305          0.8              0.1  1527.061329   1460.077321  1094.717294
# 306          0.8              0.1  1569.297506   1542.914977  1106.726514
# 307          0.8              0.1  1495.224197   1443.324009  1076.431722
#
#      actual_shopper_visits
# 301                    876
# 302                   1275
# 303                   1217
# 304                   1216
# 305                   1167
# 306                   1181
# 307                   1099

# %%
### Overpred demand and under pred supply

bt5.loc[bt5.zone_id == 785][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 140    2021-05-09     Sunday   1616.164829       1616.164829
# 141    2021-05-10     Monday   1533.989728       1533.989728
# 142    2021-05-11    Tuesday    885.616835         11.096897
# 143    2021-05-12  Wednesday    870.065081          0.000000
# 144    2021-05-13   Thursday   1058.723900          0.000000
# 145    2021-05-14     Friday   1282.680894          0.000000
# 146    2021-05-15   Saturday   1356.921390        580.712573
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 140       1616.164829                          1138.032261
# 141       1533.989728                           772.931793
# 142       1358.118279                           244.642397
# 143       1321.371607                           334.340335
# 144       1301.879691                           485.114229
# 145       1282.680894                           195.138649
# 146       1356.921390                           612.072029
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 140                            339.393918                       13.428194
# 141                            152.349525                        7.862999
# 142                            130.937599                        2.846619
# 143                            148.534893                        3.951482
# 144                            148.468028                        5.919729
# 145                            120.495181                        2.377841
# 146                            139.827159                        7.404713
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 140                         4.004673  23.931414  12.683333
# 141                         1.549845   8.479862   5.350000
# 142                         1.523569   6.495303   4.383333
# 143                         1.755495   5.930271   3.850000
# 144                         1.811719   5.397016   3.433333
# 145                         1.468281   6.194059   4.366667
# 146                         1.691598   7.153684   4.916667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 140                             62.83   6767.994558       7721.678615
# 141                            100.00   6553.319014       6203.858671
# 142                            100.00   5854.202704       5169.527527
# 143                            100.00   5756.999274       4877.939557
# 144                            100.00   5713.419820       4897.387205
# 145                            100.00   5743.771612       4515.007939
# 146                            100.00   5759.468404       5026.034603
#
#      ideal_ratio  ideal_ratio_old   demand_pred  total_demand  supply_pred  \
# 140         0.65         0.732985  10412.299320   8474.946233  4697.400374
# 141         0.65         0.612015  10082.029252   9829.986581  5288.831376
# 142         0.65         0.569457   9006.465699   8594.137989  5304.577517
# 143         0.65         0.541617   8856.921960   8461.137973  5217.025706
# 144         0.65         0.548084   8789.876646   8194.872829  5056.362164
# 145         0.65         0.517636   8836.571711   8206.548035  4906.835003
# 146         0.65         0.555113   8860.720622   8265.979654  4733.319907
#
#      actual_shopper_visits
# 140                   4686
# 141                   5577
# 142                   5750
# 143                   5688
# 144                   5714
# 145                   5484
# 146                   5164

# %%
### larger gaps look correct

bt5.loc[bt5.zone_id == 714][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 231    2021-05-09     Sunday   1343.293845       1343.293845
# 232    2021-05-10     Monday    986.604285        998.290520
# 233    2021-05-11    Tuesday    579.268297          0.000000
# 234    2021-05-12  Wednesday    624.944538          0.000000
# 235    2021-05-13   Thursday    829.094952          0.000000
# 236    2021-05-14     Friday   1035.482809          0.000000
# 237    2021-05-15   Saturday   1152.420570        675.225401
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 231       1343.293845                           842.653335
# 232       1152.868521                           352.903560
# 233       1033.778226                           310.370436
# 234       1030.115371                           522.733088
# 235       1010.278184                           211.724339
# 236       1035.482809                           103.470751
# 237       1152.420570                           325.580672
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 231                            527.570463                       19.434766
# 232                             63.963128                        8.043440
# 233                             75.915341                        7.057201
# 234                            514.448550                       11.332412
# 235                             94.123220                        5.441241
# 236                             47.286780                        2.499909
# 237                             57.532891                        7.615499
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 231                        12.167766  41.768733  20.233333
# 232                         1.457859  14.944269   6.550000
# 233                         1.726162  15.339531   5.875000
# 234                        11.152810  44.457344  18.750000
# 235                         2.418934  23.598321   8.233333
# 236                         1.142474  17.648716   7.016667
# 237                         1.345724  18.838111   7.266667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 231                              0.75   3298.410217       4095.249592
# 232                            100.00   2833.608740       2838.153023
# 233                             91.73   2546.803207       2177.196907
# 234                              0.00   2538.435088       2125.618169
# 235                             92.19   2584.045270       2151.518002
# 236                            100.00   2686.210853       1966.322209
# 237                            100.00   2754.622260       2426.541558
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 231         0.63         0.761585  5235.571774   4335.803945  2143.450459
# 232         0.63         0.634765  4497.791652   4387.470753  2242.622833
# 233         0.63         0.515387  4042.544773   4397.925529  2199.815661
# 234         0.63         0.499928  4029.262045   4612.725699  2164.087013
# 235         0.63         0.518971  4101.659158   3891.104018  2087.409040
# 236         0.63         0.452345  4263.826751   4138.980505  2052.767324
# 237         0.63         0.515415  4372.416286   4275.237583  2054.107443
#
#      actual_shopper_visits
# 231                   2092
# 232                   2778
# 233                   2638
# 234                   2489
# 235                   2454
# 236                   2433
# 237                   2304

# %%
### larger gaps look correct

bt5.loc[bt5.zone_id == 943][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 175    2021-05-09     Sunday   1730.118766       1730.118766
# 176    2021-05-10     Monday   1563.957324       1154.931167
# 177    2021-05-11    Tuesday   1462.418071        952.506035
# 178    2021-05-12  Wednesday   1421.430305        995.680030
# 179    2021-05-13   Thursday   1354.126302        168.075321
# 180    2021-05-14     Friday   1381.475247        713.417577
# 181    2021-05-15   Saturday   1408.401051       1208.386574
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 175       1730.118766                          1260.073421
# 176       1563.957324                           519.547259
# 177       1462.418071                           357.570513
# 178       1421.430305                           344.395892
# 179       1354.126302                           363.398795
# 180       1381.475247                           309.554202
# 181       1408.401051                           455.591227
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 175                            806.892977                       20.318153
# 176                             41.233617                        7.968357
# 177                             23.864376                        6.513048
# 178                             41.251278                        7.157426
# 179                             40.146702                        7.548662
# 180                             33.032048                        6.221208
# 181                             49.790310                        8.529504
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 175                        13.010809  42.238866  20.983333
# 176                         0.632405  21.539227   9.766667
# 177                         0.434683   8.960253   4.416667
# 178                         0.857307   7.359352   4.216667
# 179                         0.833943   6.000845   3.200000
# 180                         0.663855   6.768094   4.116667
# 181                         0.932166   8.857251   4.533333
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 175                               0.0   4282.688801       3862.944727
# 176                             100.0   3835.631268       3331.212151
# 177                             100.0   3408.001434       3307.348640
# 178                             100.0   3355.161725       3232.927638
# 179                             100.0   3301.093743       2923.342573
# 180                             100.0   3344.526156       3030.786544
# 181                             100.0   3347.948208       3190.866260
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 175          0.6         0.732817  7137.814668   6201.712361  2467.785804
# 176          0.6         0.648903  6392.718780   6520.130158  2653.582485
# 177          0.6         0.662848  5680.002389   5490.063997  2619.390199
# 178          0.6         0.650064  5591.936209   4811.727964  2634.400234
# 179          0.6         0.613217  5501.822906   4814.082036  2572.772694
# 180          0.6         0.636342  5574.210261   4975.789363  2534.457648
# 181          0.6         0.644121  5579.913681   5341.356494  2462.466939
#
#      actual_shopper_visits
# 175                   2406
# 176                   3057
# 177                   3038
# 178                   3027
# 179                   2937
# 180                   2819
# 181                   2664

# %%
### larger gaps look correct -- high TTA's

bt5.loc[bt5.zone_id == 786][[
    'pred_for_date', 'dow', 'delivery_gap', 'delivery_gap_old', 'max_delivery_gap',
    'solvable_supply_lost_demand_pre_inc', 'solvable_supply_lost_demand_post_inc',
    'solvable_supply_ld_pct_pre_inc', 'solvable_supply_ld_pct_post_inc',
    'avg_tta', 'p50_tta', 'time_based_capacity_availability',
    
    'ideal_supply', 'ideal_supply_old', 'ideal_ratio', 'ideal_ratio_old',
    
    'demand_pred', 'total_demand',
    'supply_pred', 'actual_shopper_visits'
]]
# Out:
#     pred_for_date        dow  delivery_gap  delivery_gap_old  \
# 595    2021-05-09     Sunday    546.741733        546.741733
# 596    2021-05-10     Monday    482.750693         68.949767
# 597    2021-05-11    Tuesday    314.731908          0.000000
# 598    2021-05-12  Wednesday    301.294030          0.000000
# 599    2021-05-13   Thursday    410.005679          0.000000
# 600    2021-05-14     Friday    422.093569          0.000000
# 601    2021-05-15   Saturday    457.761242        126.565599
#
#      max_delivery_gap  solvable_supply_lost_demand_pre_inc  \
# 595        546.741733                           415.113204
# 596        482.750693                            82.323964
# 597        429.757027                           169.695554
# 598        423.662481                            67.402402
# 599        421.236027                            67.052771
# 600        422.093569                            66.345299
# 601        457.761242                           185.954368
#
#      solvable_supply_lost_demand_post_inc  solvable_supply_ld_pct_pre_inc  \
# 595                            190.466087                       14.113083
# 596                             43.386461                        2.510076
# 597                             21.334508                        5.611354
# 598                             56.624456                        2.135748
# 599                             37.190794                        2.532724
# 600                             33.575664                        2.360875
# 601                             41.217748                        6.873585
#
#      solvable_supply_ld_pct_post_inc    avg_tta    p50_tta  \
# 595                         6.475495  45.664420  24.033333
# 596                         1.322863  15.877920   7.150000
# 597                         0.705472  13.278823   5.416667
# 598                         1.794233  34.711028  15.900000
# 599                         1.404774  17.229438   6.700000
# 600                         1.194778  13.255088   5.333333
# 601                         1.523566  13.935922   6.116667
#
#      time_based_capacity_availability  ideal_supply  ideal_supply_old  \
# 595                             71.54   2188.920172       2146.039354
# 596                            100.00   1980.467768       1688.608761
# 597                            100.00   1767.214980       1406.667011
# 598                             93.31   1723.739206       1436.475715
# 599                            100.00   1739.037990       1290.167142
# 600                            100.00   1770.923815       1225.625377
# 601                            100.00   1766.679908       1529.352645
#
#      ideal_ratio  ideal_ratio_old  demand_pred  total_demand  supply_pred  \
# 595          0.6         0.536861  3648.200286   2941.336133  1539.528742
# 596          0.6         0.468006  3300.779614   3279.740046  1607.202869
# 597          0.6         0.436287  2945.358300   3024.146274  1579.259732
# 598          0.6         0.441480  2872.898677   3155.914749  1543.808946
# 599          0.6         0.402257  2898.396649   2647.456962  1494.186048
# 600          0.6         0.386340  2951.539692   2810.200084  1512.540974
# 601          0.6         0.429602  2944.466514   2705.347673  1490.536045
#
#      actual_shopper_visits
# 595                   1465
# 596                   1983
# 597                   1868
# 598                   1705
# 599                   1768
# 600                   1688
# 601                   1588
